# %% [markdown]
# Code adapted from: https://github.com/ahmetumutdurmus/zaremba/blob/master/main.py
#
# See also relevant paper: https://arxiv.org/pdf/1409.2329.pdf)

# %% [markdown]
# **Imports**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import json
import numpy as np
from google.colab import drive
drive.mount('Google_drive')


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 
print("We're using", device)
# Out:
# Mounted at Google_drive
# We're using cuda

# %% [markdown]
# **Pre-processing**

# %%
# Define data loaders
def data_load():
    with open("/content/Google_drive/MyDrive/Deep Learning/Hw/ex2_303142897_206295917/PTB/train/ptb.train.txt") as f:
        file = f.read()
        trn = file[1:].split(' ')
    with open("/content/Google_drive/MyDrive/Deep Learning/Hw/ex2_303142897_206295917/PTB/valid/ptb.valid.txt") as f:
        file = f.read()
        vld = file[1:].split(' ')
    with open("/content/Google_drive/MyDrive/Deep Learning/Hw/ex2_303142897_206295917/PTB/test/ptb.test.txt") as f:
        file = f.read()
        tst = file[1:].split(' ')
    words = sorted(set(trn))
    char2ind = {c: i for i, c in enumerate(words)}
    trn = [char2ind[c] for c in trn]
    vld = [char2ind[c] for c in vld]
    tst = [char2ind[c] for c in tst]
    return np.array(trn).reshape(-1, 1), np.array(vld).reshape(-1, 1), np.array(tst).reshape(-1, 1), len(words)

# Create minibatches of the data
def minibatch(data, batch_size, seq_length):
    data = torch.tensor(data, dtype = torch.int64)
    num_batches = data.size(0)//batch_size
    data = data[:num_batches*batch_size]
    data=data.view(batch_size,-1)
    dataset = []
    for i in range(0,data.size(1)-1,seq_length):
        seqlen=int(np.min([seq_length,data.size(1)-1-i]))
        if seqlen<data.size(1)-1-i:
            x=data[:,i:i+seqlen].transpose(1, 0)
            y=data[:,i+1:i+seqlen+1].transpose(1, 0)
            dataset.append((x, y))
    return dataset

# %% [markdown]
# **Verify data source from Google drive**

# %%
# verify data location
# %ls Google_drive/MyDrive/'Deep Learning'/Hw/ex2_303142897_206295917/PTB/train/ptb.train.txt
# !realpath Google_drive/MyDrive/'Deep Learning'/Hw/ex2_303142897_206295917/PTB/train/ptb.train.txt
train, validation, test, words_len = data_load()
print(words_len)
# Out:
# 'Google_drive/MyDrive/Deep Learning/Hw/ex2_303142897_206295917/PTB/train/ptb.train.txt'
# /content/Google_drive/MyDrive/Deep Learning/Hw/ex2_303142897_206295917/PTB/train/ptb.train.txt
# 10000

# %%
#Embedding module
class Embed(nn.Module): #embedding is efficient when we have a large number of input features
    def __init__(self, vocab_size, embed_size):
        super().__init__()
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.W = nn.Parameter(torch.Tensor(vocab_size, embed_size))

    def forward(self, x):
        return self.W[x]

    def __repr__(self):
        return "Embedding(vocab: {}, embedding: {})".format(self.vocab_size, self.embed_size)

class Linear(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.W = nn.Parameter(torch.Tensor(hidden_size, input_size))
        self.b = nn.Parameter(torch.Tensor(hidden_size))

    def forward(self, x):
        z = torch.addmm(self.b, x.view(-1, x.size(2)), self.W.t())
        return z

    def __repr__(self):
        return "FC(input: {}, output: {})".format(self.input_size, self.hidden_size)

class Model(nn.Module):
    def __init__(self, vocab_size, hidden_size, layer_num, dropout, winit, base):
        super().__init__()
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size
        self.layer_num = layer_num
        self.winit = winit
        self.embed = Embed(vocab_size, hidden_size)
        if base == 'gru':
          self.rnns = [nn.GRU(hidden_size, hidden_size) for i in range(layer_num)] #two GRU layers with 200 units per layer
        else:
          self.rnns = [nn.LSTM(hidden_size, hidden_size) for i in range(layer_num)] #two LSTM layers with 200 units per layer
        self.rnns = nn.ModuleList(self.rnns)
        self.fc = Linear(hidden_size, vocab_size) 
        self.dropout = nn.Dropout(p=dropout)
        self.reset_parameters() #weights are reset uniformly when initializing the model
        
    def reset_parameters(self): #LSTM hidden layers weights initialized uniformly between -0.1 to 0.1
        for param in self.parameters():
            nn.init.uniform_(param, -self.winit, self.winit) 
            
    def state_init(self, batch_size,base): #hidden states are initialized to zero, input of gru is h_0 and input of lstm is (h_0, c_0) 
        dev = next(self.parameters()).device
        if base == 'gru':
          states = [(torch.zeros(1, batch_size, layer.hidden_size, device = dev)) for layer in self.rnns]
        else:
          states = [(torch.zeros(1, batch_size, layer.hidden_size, device = dev), torch.zeros(1, batch_size, layer.hidden_size, device = dev)) for layer in self.rnns]
        return states 

    # detach to complete truncated backpropagation through time (BPTT)
    def detach(self, states, base):
      if base == 'lstm':
        return [(h.detach(), c.detach()) for (h,c) in states] # returns tensors that don't require a gradient
      else:
        return [h.detach() for h in states] #gru layers input of shape h_0

    def forward(self, x, states):
        x = self.embed(x)
        x = self.dropout(x)
        for i, rnn in enumerate(self.rnns):
            x, states[i] = rnn(x, states[i])
            x = self.dropout(x)
        scores = self.fc(x)
        return scores, states

# %%
def nll_loss(scores, y):
    batch_size = y.size(1)
    expscores = scores.exp()
    probabilities = expscores / expscores.sum(1, keepdim = True)
    answerprobs = probabilities[range(len(y.reshape(-1))), y.reshape(-1)]
    return torch.mean(-torch.log(answerprobs) * batch_size)


def perplexity(data,model,base):
  with torch.no_grad():
    losses = []
    states = model.state_init(20,base)
    for x,y in data:
      x, y = x.to(device), y.to(device)
      scores, states = model(x,states)
      loss = nll_loss(scores, y)
      losses.append(loss.data.item()/20)
    return np.exp(np.mean(losses))

# %%
def train_one_epoch(data, model, lr, max_norm,base, batch_size):
    trn, vld, tst = data
    total_words = 0
    states = model.state_init(batch_size, base) # batch size of 20 according to article
    model.train()
    for i, (x, y) in enumerate(trn):
        x, y = x.to(device), y.to(device)
        total_words += x.numel()
        model.zero_grad()
        states = model.detach(states, base)
        scores, states = model(x, states)
        loss = nll_loss(scores, y)
        loss.backward()
        with torch.no_grad():
            norm = nn.utils.clip_grad_norm_(model.parameters(), max_norm)
            for param in model.parameters():
                param -= lr * param.grad
        if i % (len(trn)//10) == 0:
            print("batch no = {:d} / {:d}, ".format(i, len(trn)) +
                  "train loss = {:.3f}, ".format(loss.item()/batch_size) + #calculate loss
                  "lr = {:.3f}, ".format(lr))
    model.eval()
    val_perp = perplexity(vld, model,base)
    print("Validation set perplexity : {:.3f}".format(val_perp))
    print("*************************************************\n")
    return val_perp

# %%
def main(data,epochs,epoch_threshold,lr,model,model_name,base,lr_factor, batch_size, seq_length, max_norm):
  train, validation, test, word_len = data_load()
  train = minibatch(train,batch_size, seq_length)
  validation = minibatch(validation, batch_size, seq_length)
  test = minibatch(test,batch_size, seq_length)
  output_data = {"model": model_name,
                 "train_perp": [],
                 "test_perp":[],
                 "val_perp":[]
                 }
  best_perp = np.Inf
  for epoch in range(1, epochs + 1):
      if epoch > epoch_threshold: 
        lr = lr / lr_factor # after epoch threshold, learning rate decreased by a factor for each epoch
      print(f'Epoch {epoch}/{epochs}')
      val_perp = train_one_epoch((train,validation,test), model,lr, max_norm ,base, batch_size)   
      model.eval()   
      test_perp = perplexity(test, model,base)
      train_perp = perplexity(train, model,base)
      output_data["train_perp"].append(train_perp)
      output_data["test_perp"].append(test_perp)
      output_data["val_perp"].append(val_perp)
      filename = model_name + '.json'
      if test_perp < best_perp:
        state = {
                'model': model.state_dict(),
                'train_perp': train_perp,
                'test_perp': test_perp,
                'epoch': epoch,
                }
        best_perp = test_perp
        torch.save(state, model_name + '.pt')
        with open(filename, 'w', encoding='utf-8') as f:
          json.dump(output_data, f, indent=4)
      print("Test set perplexity : {:.3f}".format(test_perp))
      print("Training over")

# %%
# Running LSTM model without dropout
batch_size = 20
seq_length = 20
base = 'lstm'

train, validation, test, words_len = data_load()
train = minibatch(train, batch_size, seq_length)
validation = minibatch(validation, batch_size, seq_length)
test = minibatch(test, batch_size, seq_length)

hidden_size = 200
layer_num = 2
dropout = 0
w_init = 0.1

model_lstm = Model(words_len, hidden_size, layer_num, dropout, w_init, base) #LSTM model without dropout
model_lstm.to(device)

num_epochs = 13
epoch_threshold = 4
lr = 1
model_name = "LSTM"
lr_factor = 2
max_norm = 5

main((train,validation,test), num_epochs, epoch_threshold, lr,model_lstm, model_name, base, lr_factor, batch_size, seq_length, max_norm)
# Out:
# Epoch 1/13
# batch no = 0 / 2323, train loss = 9.223, lr = 1.000,
# batch no = 232 / 2323, train loss = 6.282, lr = 1.000,
# batch no = 464 / 2323, train loss = 5.981, lr = 1.000,
# batch no = 696 / 2323, train loss = 5.749, lr = 1.000,
# batch no = 928 / 2323, train loss = 5.272, lr = 1.000,
# batch no = 1160 / 2323, train loss = 5.411, lr = 1.000,
# batch no = 1392 / 2323, train loss = 5.572, lr = 1.000,
# batch no = 1624 / 2323, train loss = 5.182, lr = 1.000,
# batch no = 1856 / 2323, train loss = 4.930, lr = 1.000,
# batch no = 2088 / 2323, train loss = 5.500, lr = 1.000,
# batch no = 2320 / 2323, train loss = 5.341, lr = 1.000,
# Validation set perplexity : 185.841
# *************************************************
#
# Test set perplexity : 184.766
# Training over
# Epoch 2/13
# batch no = 0 / 2323, train loss = 5.715, lr = 1.000,
# batch no = 232 / 2323, train loss = 5.033, lr = 1.000,
# batch no = 464 / 2323, train loss = 5.067, lr = 1.000,
# batch no = 696 / 2323, train loss = 5.032, lr = 1.000,
# batch no = 928 / 2323, train loss = 4.677, lr = 1.000,
# batch no = 1160 / 2323, train loss = 4.964, lr = 1.000,
# batch no = 1392 / 2323, train loss = 5.162, lr = 1.000,
# batch no = 1624 / 2323, train loss = 4.833, lr = 1.000,
# batch no = 1856 / 2323, train loss = 4.529, lr = 1.000,
# batch no = 2088 / 2323, train loss = 5.099, lr = 1.000,
# batch no = 2320 / 2323, train loss = 4.944, lr = 1.000,
# Validation set perplexity : 149.525
# *************************************************
#
# Test set perplexity : 147.736
# Training over
# Epoch 3/13
# batch no = 0 / 2323, train loss = 5.437, lr = 1.000,
# batch no = 232 / 2323, train loss = 4.691, lr = 1.000,
# batch no = 464 / 2323, train loss = 4.756, lr = 1.000,
# batch no = 696 / 2323, train loss = 4.730, lr = 1.000,
# batch no = 928 / 2323, train loss = 4.451, lr = 1.000,
# batch no = 1160 / 2323, train loss = 4.747, lr = 1.000,
# batch no = 1392 / 2323, train loss = 4.945, lr = 1.000,
# batch no = 1624 / 2323, train loss = 4.649, lr = 1.000,
# batch no = 1856 / 2323, train loss = 4.352, lr = 1.000,
# batch no = 2088 / 2323, train loss = 4.808, lr = 1.000,
# batch no = 2320 / 2323, train loss = 4.715, lr = 1.000,
# Validation set perplexity : 136.800
# *************************************************
#
# Test set perplexity : 134.589
# Training over
# Epoch 4/13
# batch no = 0 / 2323, train loss = 5.300, lr = 1.000,
# batch no = 232 / 2323, train loss = 4.455, lr = 1.000,
# batch no = 464 / 2323, train loss = 4.571, lr = 1.000,
# batch no = 696 / 2323, train loss = 4.527, lr = 1.000,
# batch no = 928 / 2323, train loss = 4.295, lr = 1.000,
# batch no = 1160 / 2323, train loss = 4.614, lr = 1.000,
# batch no = 1392 / 2323, train loss = 4.687, lr = 1.000,
# batch no = 1624 / 2323, train loss = 4.507, lr = 1.000,
# batch no = 1856 / 2323, train loss = 4.189, lr = 1.000,
# batch no = 2088 / 2323, train loss = 4.602, lr = 1.000,
# batch no = 2320 / 2323, train loss = 4.547, lr = 1.000,
# Validation set perplexity : 131.343
# *************************************************
#
# Test set perplexity : 128.537
# Training over
# Epoch 5/13
# batch no = 0 / 2323, train loss = 5.192, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.300, lr = 0.500,
# batch no = 464 / 2323, train loss = 4.384, lr = 0.500,
# batch no = 696 / 2323, train loss = 4.326, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.014, lr = 0.500,
# batch no = 1160 / 2323, train loss = 4.284, lr = 0.500,
# batch no = 1392 / 2323, train loss = 4.392, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.219, lr = 0.500,
# batch no = 1856 / 2323, train loss = 3.882, lr = 0.500,
# batch no = 2088 / 2323, train loss = 4.311, lr = 0.500,
# batch no = 2320 / 2323, train loss = 4.262, lr = 0.500,
# Validation set perplexity : 119.284
# *************************************************
#
# Test set perplexity : 116.558
# Training over
# Epoch 6/13
# batch no = 0 / 2323, train loss = 4.971, lr = 0.250,
# batch no = 232 / 2323, train loss = 4.096, lr = 0.250,
# batch no = 464 / 2323, train loss = 4.167, lr = 0.250,
# batch no = 696 / 2323, train loss = 4.146, lr = 0.250,
# batch no = 928 / 2323, train loss = 3.839, lr = 0.250,
# batch no = 1160 / 2323, train loss = 4.081, lr = 0.250,
# batch no = 1392 / 2323, train loss = 4.134, lr = 0.250,
# batch no = 1624 / 2323, train loss = 4.009, lr = 0.250,
# batch no = 1856 / 2323, train loss = 3.722, lr = 0.250,
# batch no = 2088 / 2323, train loss = 4.051, lr = 0.250,
# batch no = 2320 / 2323, train loss = 4.023, lr = 0.250,
# Validation set perplexity : 117.840
# *************************************************
#
# Test set perplexity : 114.966
# Training over
# Epoch 7/13
# batch no = 0 / 2323, train loss = 4.858, lr = 0.125,
# batch no = 232 / 2323, train loss = 3.970, lr = 0.125,
# batch no = 464 / 2323, train loss = 4.068, lr = 0.125,
# batch no = 696 / 2323, train loss = 4.033, lr = 0.125,
# batch no = 928 / 2323, train loss = 3.737, lr = 0.125,
# batch no = 1160 / 2323, train loss = 3.956, lr = 0.125,
# batch no = 1392 / 2323, train loss = 3.994, lr = 0.125,
# batch no = 1624 / 2323, train loss = 3.893, lr = 0.125,
# batch no = 1856 / 2323, train loss = 3.612, lr = 0.125,
# batch no = 2088 / 2323, train loss = 3.910, lr = 0.125,
# batch no = 2320 / 2323, train loss = 3.902, lr = 0.125,
# Validation set perplexity : 118.276
# *************************************************
#
# Test set perplexity : 115.100
# Training over
# Epoch 8/13
# batch no = 0 / 2323, train loss = 4.794, lr = 0.062,
# batch no = 232 / 2323, train loss = 3.892, lr = 0.062,
# batch no = 464 / 2323, train loss = 3.997, lr = 0.062,
# batch no = 696 / 2323, train loss = 3.971, lr = 0.062,
# batch no = 928 / 2323, train loss = 3.672, lr = 0.062,
# batch no = 1160 / 2323, train loss = 3.887, lr = 0.062,
# batch no = 1392 / 2323, train loss = 3.920, lr = 0.062,
# batch no = 1624 / 2323, train loss = 3.837, lr = 0.062,
# batch no = 1856 / 2323, train loss = 3.540, lr = 0.062,
# batch no = 2088 / 2323, train loss = 3.828, lr = 0.062,
# batch no = 2320 / 2323, train loss = 3.842, lr = 0.062,
# Validation set perplexity : 118.662
# *************************************************
#
# Test set perplexity : 115.161
# Training over
# Epoch 9/13
# batch no = 0 / 2323, train loss = 4.768, lr = 0.031,
# batch no = 232 / 2323, train loss = 3.845, lr = 0.031,
# batch no = 464 / 2323, train loss = 3.962, lr = 0.031,
# batch no = 696 / 2323, train loss = 3.940, lr = 0.031,
# batch no = 928 / 2323, train loss = 3.636, lr = 0.031,
# batch no = 1160 / 2323, train loss = 3.852, lr = 0.031,
# batch no = 1392 / 2323, train loss = 3.876, lr = 0.031,
# batch no = 1624 / 2323, train loss = 3.820, lr = 0.031,
# batch no = 1856 / 2323, train loss = 3.491, lr = 0.031,
# batch no = 2088 / 2323, train loss = 3.789, lr = 0.031,
# batch no = 2320 / 2323, train loss = 3.813, lr = 0.031,
# Validation set perplexity : 118.761
# *************************************************
#
# Test set perplexity : 115.004
# Training over
# Epoch 10/13
# batch no = 0 / 2323, train loss = 4.753, lr = 0.016,
# batch no = 232 / 2323, train loss = 3.815, lr = 0.016,
# batch no = 464 / 2323, train loss = 3.947, lr = 0.016,
# batch no = 696 / 2323, train loss = 3.921, lr = 0.016,
# batch no = 928 / 2323, train loss = 3.620, lr = 0.016,
# batch no = 1160 / 2323, train loss = 3.834, lr = 0.016,
# batch no = 1392 / 2323, train loss = 3.851, lr = 0.016,
# batch no = 1624 / 2323, train loss = 3.810, lr = 0.016,
# batch no = 1856 / 2323, train loss = 3.465, lr = 0.016,
# batch no = 2088 / 2323, train loss = 3.768, lr = 0.016,
# batch no = 2320 / 2323, train loss = 3.797, lr = 0.016,
# Validation set perplexity : 118.505
# *************************************************
#
# Test set perplexity : 114.640
# Training over
# Epoch 11/13
# batch no = 0 / 2323, train loss = 4.742, lr = 0.008,
# batch no = 232 / 2323, train loss = 3.800, lr = 0.008,
# batch no = 464 / 2323, train loss = 3.939, lr = 0.008,
# batch no = 696 / 2323, train loss = 3.908, lr = 0.008,
# batch no = 928 / 2323, train loss = 3.612, lr = 0.008,
# batch no = 1160 / 2323, train loss = 3.823, lr = 0.008,
# batch no = 1392 / 2323, train loss = 3.837, lr = 0.008,
# batch no = 1624 / 2323, train loss = 3.803, lr = 0.008,
# batch no = 1856 / 2323, train loss = 3.452, lr = 0.008,
# batch no = 2088 / 2323, train loss = 3.756, lr = 0.008,
# batch no = 2320 / 2323, train loss = 3.787, lr = 0.008,
# Validation set perplexity : 118.097
# *************************************************
#
# Test set perplexity : 114.224
# Training over
# Epoch 12/13
# batch no = 0 / 2323, train loss = 4.736, lr = 0.004,
# batch no = 232 / 2323, train loss = 3.793, lr = 0.004,
# batch no = 464 / 2323, train loss = 3.934, lr = 0.004,
# batch no = 696 / 2323, train loss = 3.901, lr = 0.004,
# batch no = 928 / 2323, train loss = 3.606, lr = 0.004,
# batch no = 1160 / 2323, train loss = 3.817, lr = 0.004,
# batch no = 1392 / 2323, train loss = 3.828, lr = 0.004,
# batch no = 1624 / 2323, train loss = 3.798, lr = 0.004,
# batch no = 1856 / 2323, train loss = 3.445, lr = 0.004,
# batch no = 2088 / 2323, train loss = 3.749, lr = 0.004,
# batch no = 2320 / 2323, train loss = 3.782, lr = 0.004,
# Validation set perplexity : 117.759
# *************************************************
#
# Test set perplexity : 113.896
# Training over
# Epoch 13/13
# batch no = 0 / 2323, train loss = 4.733, lr = 0.002,
# batch no = 232 / 2323, train loss = 3.789, lr = 0.002,
# batch no = 464 / 2323, train loss = 3.931, lr = 0.002,
# batch no = 696 / 2323, train loss = 3.897, lr = 0.002,
# batch no = 928 / 2323, train loss = 3.603, lr = 0.002,
# batch no = 1160 / 2323, train loss = 3.813, lr = 0.002,
# batch no = 1392 / 2323, train loss = 3.823, lr = 0.002,
# batch no = 1624 / 2323, train loss = 3.795, lr = 0.002,
# batch no = 1856 / 2323, train loss = 3.442, lr = 0.002,
# batch no = 2088 / 2323, train loss = 3.745, lr = 0.002,
# batch no = 2320 / 2323, train loss = 3.779, lr = 0.002,
# Validation set perplexity : 117.559
# *************************************************
#
# Test set perplexity : 113.695
# Training over

# %%
# Running LSTM model with 30% dropout
batch_size = 20
seq_length = 20
base = 'lstm'

train, validation, test, words_len = data_load()

hidden_size = 200
layer_num = 2
dropout = 0.3
w_init = 0.1

model_lstm_dropout = Model(words_len, hidden_size, layer_num , dropout, w_init, base) #LSTM model with 30% dropout
model_lstm_dropout.to(device)

num_epochs = 25
epoch_threshold = 8
lr = 1
model_name = "LSTM_dropout"
lr_factor = 1.5
max_norm = 5

main((train,validation,test), num_epochs, epoch_threshold, lr, model_lstm_dropout, model_name, base, lr_factor, batch_size, seq_length, max_norm)
# Out:
# Epoch 1/25
# batch no = 0 / 2323, train loss = 9.221, lr = 1.000,
# batch no = 232 / 2323, train loss = 6.311, lr = 1.000,
# batch no = 464 / 2323, train loss = 6.043, lr = 1.000,
# batch no = 696 / 2323, train loss = 5.831, lr = 1.000,
# batch no = 928 / 2323, train loss = 5.423, lr = 1.000,
# batch no = 1160 / 2323, train loss = 5.533, lr = 1.000,
# batch no = 1392 / 2323, train loss = 5.674, lr = 1.000,
# batch no = 1624 / 2323, train loss = 5.329, lr = 1.000,
# batch no = 1856 / 2323, train loss = 5.106, lr = 1.000,
# batch no = 2088 / 2323, train loss = 5.687, lr = 1.000,
# batch no = 2320 / 2323, train loss = 5.521, lr = 1.000,
# Validation set perplexity : 196.468
# *************************************************
#
# Test set perplexity : 193.867
# Training over
# Epoch 2/25
# batch no = 0 / 2323, train loss = 5.872, lr = 1.000,
# batch no = 232 / 2323, train loss = 5.220, lr = 1.000,
# batch no = 464 / 2323, train loss = 5.260, lr = 1.000,
# batch no = 696 / 2323, train loss = 5.176, lr = 1.000,
# batch no = 928 / 2323, train loss = 4.920, lr = 1.000,
# batch no = 1160 / 2323, train loss = 5.201, lr = 1.000,
# batch no = 1392 / 2323, train loss = 5.344, lr = 1.000,
# batch no = 1624 / 2323, train loss = 5.036, lr = 1.000,
# batch no = 1856 / 2323, train loss = 4.808, lr = 1.000,
# batch no = 2088 / 2323, train loss = 5.359, lr = 1.000,
# batch no = 2320 / 2323, train loss = 5.284, lr = 1.000,
# Validation set perplexity : 156.296
# *************************************************
#
# Test set perplexity : 153.490
# Training over
# Epoch 3/25
# batch no = 0 / 2323, train loss = 5.673, lr = 1.000,
# batch no = 232 / 2323, train loss = 4.957, lr = 1.000,
# batch no = 464 / 2323, train loss = 4.976, lr = 1.000,
# batch no = 696 / 2323, train loss = 5.064, lr = 1.000,
# batch no = 928 / 2323, train loss = 4.738, lr = 1.000,
# batch no = 1160 / 2323, train loss = 5.084, lr = 1.000,
# batch no = 1392 / 2323, train loss = 5.140, lr = 1.000,
# batch no = 1624 / 2323, train loss = 4.919, lr = 1.000,
# batch no = 1856 / 2323, train loss = 4.692, lr = 1.000,
# batch no = 2088 / 2323, train loss = 5.171, lr = 1.000,
# batch no = 2320 / 2323, train loss = 5.159, lr = 1.000,
# Validation set perplexity : 140.245
# *************************************************
#
# Test set perplexity : 137.764
# Training over
# Epoch 4/25
# batch no = 0 / 2323, train loss = 5.559, lr = 1.000,
# batch no = 232 / 2323, train loss = 4.831, lr = 1.000,
# batch no = 464 / 2323, train loss = 4.852, lr = 1.000,
# batch no = 696 / 2323, train loss = 4.831, lr = 1.000,
# batch no = 928 / 2323, train loss = 4.665, lr = 1.000,
# batch no = 1160 / 2323, train loss = 4.939, lr = 1.000,
# batch no = 1392 / 2323, train loss = 5.132, lr = 1.000,
# batch no = 1624 / 2323, train loss = 4.855, lr = 1.000,
# batch no = 1856 / 2323, train loss = 4.593, lr = 1.000,
# batch no = 2088 / 2323, train loss = 5.111, lr = 1.000,
# batch no = 2320 / 2323, train loss = 4.988, lr = 1.000,
# Validation set perplexity : 132.279
# *************************************************
#
# Test set perplexity : 128.396
# Training over
# Epoch 5/25
# batch no = 0 / 2323, train loss = 5.479, lr = 1.000,
# batch no = 232 / 2323, train loss = 4.719, lr = 1.000,
# batch no = 464 / 2323, train loss = 4.891, lr = 1.000,
# batch no = 696 / 2323, train loss = 4.801, lr = 1.000,
# batch no = 928 / 2323, train loss = 4.603, lr = 1.000,
# batch no = 1160 / 2323, train loss = 4.894, lr = 1.000,
# batch no = 1392 / 2323, train loss = 4.997, lr = 1.000,
# batch no = 1624 / 2323, train loss = 4.787, lr = 1.000,
# batch no = 1856 / 2323, train loss = 4.515, lr = 1.000,
# batch no = 2088 / 2323, train loss = 5.003, lr = 1.000,
# batch no = 2320 / 2323, train loss = 4.915, lr = 1.000,
# Validation set perplexity : 126.325
# *************************************************
#
# Test set perplexity : 122.406
# Training over
# Epoch 6/25
# batch no = 0 / 2323, train loss = 5.428, lr = 1.000,
# batch no = 232 / 2323, train loss = 4.561, lr = 1.000,
# batch no = 464 / 2323, train loss = 4.745, lr = 1.000,
# batch no = 696 / 2323, train loss = 4.675, lr = 1.000,
# batch no = 928 / 2323, train loss = 4.534, lr = 1.000,
# batch no = 1160 / 2323, train loss = 4.802, lr = 1.000,
# batch no = 1392 / 2323, train loss = 4.939, lr = 1.000,
# batch no = 1624 / 2323, train loss = 4.747, lr = 1.000,
# batch no = 1856 / 2323, train loss = 4.410, lr = 1.000,
# batch no = 2088 / 2323, train loss = 4.919, lr = 1.000,
# batch no = 2320 / 2323, train loss = 4.913, lr = 1.000,
# Validation set perplexity : 124.447
# *************************************************
#
# Test set perplexity : 120.153
# Training over
# Epoch 7/25
# batch no = 0 / 2323, train loss = 5.378, lr = 1.000,
# batch no = 232 / 2323, train loss = 4.624, lr = 1.000,
# batch no = 464 / 2323, train loss = 4.665, lr = 1.000,
# batch no = 696 / 2323, train loss = 4.646, lr = 1.000,
# batch no = 928 / 2323, train loss = 4.531, lr = 1.000,
# batch no = 1160 / 2323, train loss = 4.796, lr = 1.000,
# batch no = 1392 / 2323, train loss = 4.882, lr = 1.000,
# batch no = 1624 / 2323, train loss = 4.792, lr = 1.000,
# batch no = 1856 / 2323, train loss = 4.458, lr = 1.000,
# batch no = 2088 / 2323, train loss = 4.951, lr = 1.000,
# batch no = 2320 / 2323, train loss = 4.907, lr = 1.000,
# Validation set perplexity : 120.572
# *************************************************
#
# Test set perplexity : 117.180
# Training over
# Epoch 8/25
# batch no = 0 / 2323, train loss = 5.378, lr = 1.000,
# batch no = 232 / 2323, train loss = 4.576, lr = 1.000,
# batch no = 464 / 2323, train loss = 4.734, lr = 1.000,
# batch no = 696 / 2323, train loss = 4.680, lr = 1.000,
# batch no = 928 / 2323, train loss = 4.472, lr = 1.000,
# batch no = 1160 / 2323, train loss = 4.764, lr = 1.000,
# batch no = 1392 / 2323, train loss = 4.844, lr = 1.000,
# batch no = 1624 / 2323, train loss = 4.651, lr = 1.000,
# batch no = 1856 / 2323, train loss = 4.421, lr = 1.000,
# batch no = 2088 / 2323, train loss = 4.849, lr = 1.000,
# batch no = 2320 / 2323, train loss = 4.827, lr = 1.000,
# Validation set perplexity : 120.792
# *************************************************
#
# Test set perplexity : 117.771
# Training over
# Epoch 9/25
# batch no = 0 / 2323, train loss = 5.385, lr = 0.667,
# batch no = 232 / 2323, train loss = 4.481, lr = 0.667,
# batch no = 464 / 2323, train loss = 4.580, lr = 0.667,
# batch no = 696 / 2323, train loss = 4.513, lr = 0.667,
# batch no = 928 / 2323, train loss = 4.355, lr = 0.667,
# batch no = 1160 / 2323, train loss = 4.705, lr = 0.667,
# batch no = 1392 / 2323, train loss = 4.778, lr = 0.667,
# batch no = 1624 / 2323, train loss = 4.607, lr = 0.667,
# batch no = 1856 / 2323, train loss = 4.306, lr = 0.667,
# batch no = 2088 / 2323, train loss = 4.725, lr = 0.667,
# batch no = 2320 / 2323, train loss = 4.655, lr = 0.667,
# Validation set perplexity : 111.870
# *************************************************
#
# Test set perplexity : 108.818
# Training over
# Epoch 10/25
# batch no = 0 / 2323, train loss = 5.301, lr = 0.444,
# batch no = 232 / 2323, train loss = 4.460, lr = 0.444,
# batch no = 464 / 2323, train loss = 4.552, lr = 0.444,
# batch no = 696 / 2323, train loss = 4.466, lr = 0.444,
# batch no = 928 / 2323, train loss = 4.241, lr = 0.444,
# batch no = 1160 / 2323, train loss = 4.503, lr = 0.444,
# batch no = 1392 / 2323, train loss = 4.676, lr = 0.444,
# batch no = 1624 / 2323, train loss = 4.554, lr = 0.444,
# batch no = 1856 / 2323, train loss = 4.248, lr = 0.444,
# batch no = 2088 / 2323, train loss = 4.639, lr = 0.444,
# batch no = 2320 / 2323, train loss = 4.665, lr = 0.444,
# Validation set perplexity : 107.400
# *************************************************
#
# Test set perplexity : 104.194
# Training over
# Epoch 11/25
# batch no = 0 / 2323, train loss = 5.237, lr = 0.296,
# batch no = 232 / 2323, train loss = 4.318, lr = 0.296,
# batch no = 464 / 2323, train loss = 4.482, lr = 0.296,
# batch no = 696 / 2323, train loss = 4.401, lr = 0.296,
# batch no = 928 / 2323, train loss = 4.151, lr = 0.296,
# batch no = 1160 / 2323, train loss = 4.567, lr = 0.296,
# batch no = 1392 / 2323, train loss = 4.585, lr = 0.296,
# batch no = 1624 / 2323, train loss = 4.492, lr = 0.296,
# batch no = 1856 / 2323, train loss = 4.160, lr = 0.296,
# batch no = 2088 / 2323, train loss = 4.534, lr = 0.296,
# batch no = 2320 / 2323, train loss = 4.557, lr = 0.296,
# Validation set perplexity : 104.301
# *************************************************
#
# Test set perplexity : 100.834
# Training over
# Epoch 12/25
# batch no = 0 / 2323, train loss = 5.202, lr = 0.198,
# batch no = 232 / 2323, train loss = 4.298, lr = 0.198,
# batch no = 464 / 2323, train loss = 4.389, lr = 0.198,
# batch no = 696 / 2323, train loss = 4.345, lr = 0.198,
# batch no = 928 / 2323, train loss = 4.206, lr = 0.198,
# batch no = 1160 / 2323, train loss = 4.472, lr = 0.198,
# batch no = 1392 / 2323, train loss = 4.555, lr = 0.198,
# batch no = 1624 / 2323, train loss = 4.455, lr = 0.198,
# batch no = 1856 / 2323, train loss = 4.081, lr = 0.198,
# batch no = 2088 / 2323, train loss = 4.567, lr = 0.198,
# batch no = 2320 / 2323, train loss = 4.509, lr = 0.198,
# Validation set perplexity : 102.481
# *************************************************
#
# Test set perplexity : 98.936
# Training over
# Epoch 13/25
# batch no = 0 / 2323, train loss = 5.144, lr = 0.132,
# batch no = 232 / 2323, train loss = 4.252, lr = 0.132,
# batch no = 464 / 2323, train loss = 4.363, lr = 0.132,
# batch no = 696 / 2323, train loss = 4.359, lr = 0.132,
# batch no = 928 / 2323, train loss = 4.193, lr = 0.132,
# batch no = 1160 / 2323, train loss = 4.437, lr = 0.132,
# batch no = 1392 / 2323, train loss = 4.503, lr = 0.132,
# batch no = 1624 / 2323, train loss = 4.359, lr = 0.132,
# batch no = 1856 / 2323, train loss = 4.052, lr = 0.132,
# batch no = 2088 / 2323, train loss = 4.473, lr = 0.132,
# batch no = 2320 / 2323, train loss = 4.485, lr = 0.132,
# Validation set perplexity : 100.980
# *************************************************
#
# Test set perplexity : 97.378
# Training over
# Epoch 14/25
# batch no = 0 / 2323, train loss = 5.064, lr = 0.088,
# batch no = 232 / 2323, train loss = 4.300, lr = 0.088,
# batch no = 464 / 2323, train loss = 4.358, lr = 0.088,
# batch no = 696 / 2323, train loss = 4.321, lr = 0.088,
# batch no = 928 / 2323, train loss = 4.205, lr = 0.088,
# batch no = 1160 / 2323, train loss = 4.360, lr = 0.088,
# batch no = 1392 / 2323, train loss = 4.423, lr = 0.088,
# batch no = 1624 / 2323, train loss = 4.398, lr = 0.088,
# batch no = 1856 / 2323, train loss = 4.040, lr = 0.088,
# batch no = 2088 / 2323, train loss = 4.481, lr = 0.088,
# batch no = 2320 / 2323, train loss = 4.577, lr = 0.088,
# Validation set perplexity : 100.353
# *************************************************
#
# Test set perplexity : 96.409
# Training over
# Epoch 15/25
# batch no = 0 / 2323, train loss = 5.127, lr = 0.059,
# batch no = 232 / 2323, train loss = 4.309, lr = 0.059,
# batch no = 464 / 2323, train loss = 4.382, lr = 0.059,
# batch no = 696 / 2323, train loss = 4.296, lr = 0.059,
# batch no = 928 / 2323, train loss = 4.050, lr = 0.059,
# batch no = 1160 / 2323, train loss = 4.427, lr = 0.059,
# batch no = 1392 / 2323, train loss = 4.481, lr = 0.059,
# batch no = 1624 / 2323, train loss = 4.279, lr = 0.059,
# batch no = 1856 / 2323, train loss = 4.057, lr = 0.059,
# batch no = 2088 / 2323, train loss = 4.436, lr = 0.059,
# batch no = 2320 / 2323, train loss = 4.466, lr = 0.059,
# Validation set perplexity : 99.806
# *************************************************
#
# Test set perplexity : 95.769
# Training over
# Epoch 16/25
# batch no = 0 / 2323, train loss = 5.102, lr = 0.039,
# batch no = 232 / 2323, train loss = 4.256, lr = 0.039,
# batch no = 464 / 2323, train loss = 4.354, lr = 0.039,
# batch no = 696 / 2323, train loss = 4.288, lr = 0.039,
# batch no = 928 / 2323, train loss = 4.101, lr = 0.039,
# batch no = 1160 / 2323, train loss = 4.372, lr = 0.039,
# batch no = 1392 / 2323, train loss = 4.507, lr = 0.039,
# batch no = 1624 / 2323, train loss = 4.310, lr = 0.039,
# batch no = 1856 / 2323, train loss = 4.035, lr = 0.039,
# batch no = 2088 / 2323, train loss = 4.433, lr = 0.039,
# batch no = 2320 / 2323, train loss = 4.448, lr = 0.039,
# Validation set perplexity : 99.551
# *************************************************
#
# Test set perplexity : 95.439
# Training over
# Epoch 17/25
# batch no = 0 / 2323, train loss = 5.092, lr = 0.026,
# batch no = 232 / 2323, train loss = 4.175, lr = 0.026,
# batch no = 464 / 2323, train loss = 4.349, lr = 0.026,
# batch no = 696 / 2323, train loss = 4.299, lr = 0.026,
# batch no = 928 / 2323, train loss = 4.074, lr = 0.026,
# batch no = 1160 / 2323, train loss = 4.455, lr = 0.026,
# batch no = 1392 / 2323, train loss = 4.558, lr = 0.026,
# batch no = 1624 / 2323, train loss = 4.370, lr = 0.026,
# batch no = 1856 / 2323, train loss = 4.021, lr = 0.026,
# batch no = 2088 / 2323, train loss = 4.381, lr = 0.026,
# batch no = 2320 / 2323, train loss = 4.570, lr = 0.026,
# Validation set perplexity : 99.283
# *************************************************
#
# Test set perplexity : 95.174
# Training over
# Epoch 18/25
# batch no = 0 / 2323, train loss = 5.055, lr = 0.017,
# batch no = 232 / 2323, train loss = 4.226, lr = 0.017,
# batch no = 464 / 2323, train loss = 4.284, lr = 0.017,
# batch no = 696 / 2323, train loss = 4.296, lr = 0.017,
# batch no = 928 / 2323, train loss = 4.086, lr = 0.017,
# batch no = 1160 / 2323, train loss = 4.362, lr = 0.017,
# batch no = 1392 / 2323, train loss = 4.482, lr = 0.017,
# batch no = 1624 / 2323, train loss = 4.288, lr = 0.017,
# batch no = 1856 / 2323, train loss = 4.065, lr = 0.017,
# batch no = 2088 / 2323, train loss = 4.411, lr = 0.017,
# batch no = 2320 / 2323, train loss = 4.460, lr = 0.017,
# Validation set perplexity : 99.213
# *************************************************
#
# Test set perplexity : 95.038
# Training over
# Epoch 19/25
# batch no = 0 / 2323, train loss = 5.118, lr = 0.012,
# batch no = 232 / 2323, train loss = 4.213, lr = 0.012,
# batch no = 464 / 2323, train loss = 4.296, lr = 0.012,
# batch no = 696 / 2323, train loss = 4.250, lr = 0.012,
# batch no = 928 / 2323, train loss = 4.037, lr = 0.012,
# batch no = 1160 / 2323, train loss = 4.422, lr = 0.012,
# batch no = 1392 / 2323, train loss = 4.453, lr = 0.012,
# batch no = 1624 / 2323, train loss = 4.369, lr = 0.012,
# batch no = 1856 / 2323, train loss = 4.007, lr = 0.012,
# batch no = 2088 / 2323, train loss = 4.371, lr = 0.012,
# batch no = 2320 / 2323, train loss = 4.374, lr = 0.012,
# Validation set perplexity : 99.065
# *************************************************
#
# Test set perplexity : 94.889
# Training over
# Epoch 20/25
# batch no = 0 / 2323, train loss = 5.132, lr = 0.008,
# batch no = 232 / 2323, train loss = 4.220, lr = 0.008,
# batch no = 464 / 2323, train loss = 4.389, lr = 0.008,
# batch no = 696 / 2323, train loss = 4.225, lr = 0.008,
# batch no = 928 / 2323, train loss = 4.163, lr = 0.008,
# batch no = 1160 / 2323, train loss = 4.513, lr = 0.008,
# batch no = 1392 / 2323, train loss = 4.519, lr = 0.008,
# batch no = 1624 / 2323, train loss = 4.312, lr = 0.008,
# batch no = 1856 / 2323, train loss = 3.993, lr = 0.008,
# batch no = 2088 / 2323, train loss = 4.406, lr = 0.008,
# batch no = 2320 / 2323, train loss = 4.424, lr = 0.008,
# Validation set perplexity : 99.006
# *************************************************
#
# Test set perplexity : 94.826
# Training over
# Epoch 21/25
# batch no = 0 / 2323, train loss = 5.080, lr = 0.005,
# batch no = 232 / 2323, train loss = 4.294, lr = 0.005,
# batch no = 464 / 2323, train loss = 4.346, lr = 0.005,
# batch no = 696 / 2323, train loss = 4.278, lr = 0.005,
# batch no = 928 / 2323, train loss = 4.058, lr = 0.005,
# batch no = 1160 / 2323, train loss = 4.435, lr = 0.005,
# batch no = 1392 / 2323, train loss = 4.440, lr = 0.005,
# batch no = 1624 / 2323, train loss = 4.391, lr = 0.005,
# batch no = 1856 / 2323, train loss = 4.080, lr = 0.005,
# batch no = 2088 / 2323, train loss = 4.362, lr = 0.005,
# batch no = 2320 / 2323, train loss = 4.439, lr = 0.005,
# Validation set perplexity : 98.951
# *************************************************
#
# Test set perplexity : 94.747
# Training over
# Epoch 22/25
# batch no = 0 / 2323, train loss = 5.101, lr = 0.003,
# batch no = 232 / 2323, train loss = 4.180, lr = 0.003,
# batch no = 464 / 2323, train loss = 4.366, lr = 0.003,
# batch no = 696 / 2323, train loss = 4.278, lr = 0.003,
# batch no = 928 / 2323, train loss = 4.036, lr = 0.003,
# batch no = 1160 / 2323, train loss = 4.402, lr = 0.003,
# batch no = 1392 / 2323, train loss = 4.464, lr = 0.003,
# batch no = 1624 / 2323, train loss = 4.349, lr = 0.003,
# batch no = 1856 / 2323, train loss = 4.117, lr = 0.003,
# batch no = 2088 / 2323, train loss = 4.435, lr = 0.003,
# batch no = 2320 / 2323, train loss = 4.406, lr = 0.003,
# Validation set perplexity : 98.915
# *************************************************
#
# Test set perplexity : 94.709
# Training over
# Epoch 23/25
# batch no = 0 / 2323, train loss = 5.168, lr = 0.002,
# batch no = 232 / 2323, train loss = 4.130, lr = 0.002,
# batch no = 464 / 2323, train loss = 4.348, lr = 0.002,
# batch no = 696 / 2323, train loss = 4.266, lr = 0.002,
# batch no = 928 / 2323, train loss = 4.079, lr = 0.002,
# batch no = 1160 / 2323, train loss = 4.397, lr = 0.002,
# batch no = 1392 / 2323, train loss = 4.446, lr = 0.002,
# batch no = 1624 / 2323, train loss = 4.337, lr = 0.002,
# batch no = 1856 / 2323, train loss = 4.060, lr = 0.002,
# batch no = 2088 / 2323, train loss = 4.386, lr = 0.002,
# batch no = 2320 / 2323, train loss = 4.384, lr = 0.002,
# Validation set perplexity : 98.881
# *************************************************
#
# Test set perplexity : 94.669
# Training over
# Epoch 24/25
# batch no = 0 / 2323, train loss = 5.154, lr = 0.002,
# batch no = 232 / 2323, train loss = 4.221, lr = 0.002,
# batch no = 464 / 2323, train loss = 4.362, lr = 0.002,
# batch no = 696 / 2323, train loss = 4.225, lr = 0.002,
# batch no = 928 / 2323, train loss = 4.121, lr = 0.002,
# batch no = 1160 / 2323, train loss = 4.397, lr = 0.002,
# batch no = 1392 / 2323, train loss = 4.531, lr = 0.002,
# batch no = 1624 / 2323, train loss = 4.302, lr = 0.002,
# batch no = 1856 / 2323, train loss = 4.040, lr = 0.002,
# batch no = 2088 / 2323, train loss = 4.447, lr = 0.002,
# batch no = 2320 / 2323, train loss = 4.491, lr = 0.002,
# Validation set perplexity : 98.859
# *************************************************
#
# Test set perplexity : 94.641
# Training over
# Epoch 25/25
# batch no = 0 / 2323, train loss = 5.064, lr = 0.001,
# batch no = 232 / 2323, train loss = 4.204, lr = 0.001,
# batch no = 464 / 2323, train loss = 4.308, lr = 0.001,
# batch no = 696 / 2323, train loss = 4.277, lr = 0.001,
# batch no = 928 / 2323, train loss = 4.034, lr = 0.001,
# batch no = 1160 / 2323, train loss = 4.447, lr = 0.001,
# batch no = 1392 / 2323, train loss = 4.421, lr = 0.001,
# batch no = 1624 / 2323, train loss = 4.410, lr = 0.001,
# batch no = 1856 / 2323, train loss = 4.068, lr = 0.001,
# batch no = 2088 / 2323, train loss = 4.377, lr = 0.001,
# batch no = 2320 / 2323, train loss = 4.398, lr = 0.001,
# Validation set perplexity : 98.849
# *************************************************
#
# Test set perplexity : 94.621
# Training over

# %%
# Running GRU model without dropout
batch_size = 20
seq_length = 20
base = 'gru'

hidden_size = 200
layer_num = 2
dropout = 0
w_init = 0.1

model_gru = Model(words_len, hidden_size, layer_num, dropout, w_init, base) #GRU model no dropout
model_gru.to(device)

num_epochs = 20
epoch_threshold = 4
lr = 0.4
model_name = "GRU"
lr_factor = 1.9
max_norm = 5
main((train,validation,test), num_epochs, epoch_threshold, lr, model_gru, model_name, base, lr_factor, batch_size, seq_length, max_norm)
# Out:
# Epoch 1/20
# batch no = 0 / 2323, train loss = 9.222, lr = 0.400,
# batch no = 232 / 2323, train loss = 6.375, lr = 0.400,
# batch no = 464 / 2323, train loss = 6.030, lr = 0.400,
# batch no = 696 / 2323, train loss = 5.783, lr = 0.400,
# batch no = 928 / 2323, train loss = 5.337, lr = 0.400,
# batch no = 1160 / 2323, train loss = 5.417, lr = 0.400,
# batch no = 1392 / 2323, train loss = 5.580, lr = 0.400,
# batch no = 1624 / 2323, train loss = 5.221, lr = 0.400,
# batch no = 1856 / 2323, train loss = 5.026, lr = 0.400,
# batch no = 2088 / 2323, train loss = 5.488, lr = 0.400,
# batch no = 2320 / 2323, train loss = 5.371, lr = 0.400,
# Validation set perplexity : 193.014
# *************************************************
#
# Test set perplexity : 189.435
# Training over
# Epoch 2/20
# batch no = 0 / 2323, train loss = 5.878, lr = 0.400,
# batch no = 232 / 2323, train loss = 5.068, lr = 0.400,
# batch no = 464 / 2323, train loss = 5.029, lr = 0.400,
# batch no = 696 / 2323, train loss = 5.015, lr = 0.400,
# batch no = 928 / 2323, train loss = 4.707, lr = 0.400,
# batch no = 1160 / 2323, train loss = 4.917, lr = 0.400,
# batch no = 1392 / 2323, train loss = 5.096, lr = 0.400,
# batch no = 1624 / 2323, train loss = 4.832, lr = 0.400,
# batch no = 1856 / 2323, train loss = 4.551, lr = 0.400,
# batch no = 2088 / 2323, train loss = 5.025, lr = 0.400,
# batch no = 2320 / 2323, train loss = 4.927, lr = 0.400,
# Validation set perplexity : 151.077
# *************************************************
#
# Test set perplexity : 148.524
# Training over
# Epoch 3/20
# batch no = 0 / 2323, train loss = 5.503, lr = 0.400,
# batch no = 232 / 2323, train loss = 4.647, lr = 0.400,
# batch no = 464 / 2323, train loss = 4.702, lr = 0.400,
# batch no = 696 / 2323, train loss = 4.697, lr = 0.400,
# batch no = 928 / 2323, train loss = 4.422, lr = 0.400,
# batch no = 1160 / 2323, train loss = 4.659, lr = 0.400,
# batch no = 1392 / 2323, train loss = 4.812, lr = 0.400,
# batch no = 1624 / 2323, train loss = 4.587, lr = 0.400,
# batch no = 1856 / 2323, train loss = 4.341, lr = 0.400,
# batch no = 2088 / 2323, train loss = 4.708, lr = 0.400,
# batch no = 2320 / 2323, train loss = 4.623, lr = 0.400,
# Validation set perplexity : 141.255
# *************************************************
#
# Test set perplexity : 138.682
# Training over
# Epoch 4/20
# batch no = 0 / 2323, train loss = 5.205, lr = 0.400,
# batch no = 232 / 2323, train loss = 4.341, lr = 0.400,
# batch no = 464 / 2323, train loss = 4.491, lr = 0.400,
# batch no = 696 / 2323, train loss = 4.478, lr = 0.400,
# batch no = 928 / 2323, train loss = 4.242, lr = 0.400,
# batch no = 1160 / 2323, train loss = 4.460, lr = 0.400,
# batch no = 1392 / 2323, train loss = 4.599, lr = 0.400,
# batch no = 1624 / 2323, train loss = 4.393, lr = 0.400,
# batch no = 1856 / 2323, train loss = 4.205, lr = 0.400,
# batch no = 2088 / 2323, train loss = 4.506, lr = 0.400,
# batch no = 2320 / 2323, train loss = 4.421, lr = 0.400,
# Validation set perplexity : 140.922
# *************************************************
#
# Test set perplexity : 138.516
# Training over
# Epoch 5/20
# batch no = 0 / 2323, train loss = 4.984, lr = 0.211,
# batch no = 232 / 2323, train loss = 4.124, lr = 0.211,
# batch no = 464 / 2323, train loss = 4.273, lr = 0.211,
# batch no = 696 / 2323, train loss = 4.248, lr = 0.211,
# batch no = 928 / 2323, train loss = 3.996, lr = 0.211,
# batch no = 1160 / 2323, train loss = 4.191, lr = 0.211,
# batch no = 1392 / 2323, train loss = 4.286, lr = 0.211,
# batch no = 1624 / 2323, train loss = 4.101, lr = 0.211,
# batch no = 1856 / 2323, train loss = 3.897, lr = 0.211,
# batch no = 2088 / 2323, train loss = 4.199, lr = 0.211,
# batch no = 2320 / 2323, train loss = 4.114, lr = 0.211,
# Validation set perplexity : 132.130
# *************************************************
#
# Test set perplexity : 129.014
# Training over
# Epoch 6/20
# batch no = 0 / 2323, train loss = 4.825, lr = 0.111,
# batch no = 232 / 2323, train loss = 3.982, lr = 0.111,
# batch no = 464 / 2323, train loss = 4.131, lr = 0.111,
# batch no = 696 / 2323, train loss = 4.086, lr = 0.111,
# batch no = 928 / 2323, train loss = 3.845, lr = 0.111,
# batch no = 1160 / 2323, train loss = 4.044, lr = 0.111,
# batch no = 1392 / 2323, train loss = 4.106, lr = 0.111,
# batch no = 1624 / 2323, train loss = 3.947, lr = 0.111,
# batch no = 1856 / 2323, train loss = 3.709, lr = 0.111,
# batch no = 2088 / 2323, train loss = 4.021, lr = 0.111,
# batch no = 2320 / 2323, train loss = 3.952, lr = 0.111,
# Validation set perplexity : 128.008
# *************************************************
#
# Test set perplexity : 124.413
# Training over
# Epoch 7/20
# batch no = 0 / 2323, train loss = 4.736, lr = 0.058,
# batch no = 232 / 2323, train loss = 3.907, lr = 0.058,
# batch no = 464 / 2323, train loss = 4.045, lr = 0.058,
# batch no = 696 / 2323, train loss = 3.985, lr = 0.058,
# batch no = 928 / 2323, train loss = 3.734, lr = 0.058,
# batch no = 1160 / 2323, train loss = 3.971, lr = 0.058,
# batch no = 1392 / 2323, train loss = 4.011, lr = 0.058,
# batch no = 1624 / 2323, train loss = 3.861, lr = 0.058,
# batch no = 1856 / 2323, train loss = 3.603, lr = 0.058,
# batch no = 2088 / 2323, train loss = 3.905, lr = 0.058,
# batch no = 2320 / 2323, train loss = 3.861, lr = 0.058,
# Validation set perplexity : 125.768
# *************************************************
#
# Test set perplexity : 122.008
# Training over
# Epoch 8/20
# batch no = 0 / 2323, train loss = 4.691, lr = 0.031,
# batch no = 232 / 2323, train loss = 3.852, lr = 0.031,
# batch no = 464 / 2323, train loss = 3.993, lr = 0.031,
# batch no = 696 / 2323, train loss = 3.926, lr = 0.031,
# batch no = 928 / 2323, train loss = 3.668, lr = 0.031,
# batch no = 1160 / 2323, train loss = 3.933, lr = 0.031,
# batch no = 1392 / 2323, train loss = 3.944, lr = 0.031,
# batch no = 1624 / 2323, train loss = 3.809, lr = 0.031,
# batch no = 1856 / 2323, train loss = 3.530, lr = 0.031,
# batch no = 2088 / 2323, train loss = 3.847, lr = 0.031,
# batch no = 2320 / 2323, train loss = 3.805, lr = 0.031,
# Validation set perplexity : 124.474
# *************************************************
#
# Test set perplexity : 120.636
# Training over
# Epoch 9/20
# batch no = 0 / 2323, train loss = 4.666, lr = 0.016,
# batch no = 232 / 2323, train loss = 3.820, lr = 0.016,
# batch no = 464 / 2323, train loss = 3.963, lr = 0.016,
# batch no = 696 / 2323, train loss = 3.899, lr = 0.016,
# batch no = 928 / 2323, train loss = 3.642, lr = 0.016,
# batch no = 1160 / 2323, train loss = 3.902, lr = 0.016,
# batch no = 1392 / 2323, train loss = 3.905, lr = 0.016,
# batch no = 1624 / 2323, train loss = 3.773, lr = 0.016,
# batch no = 1856 / 2323, train loss = 3.496, lr = 0.016,
# batch no = 2088 / 2323, train loss = 3.815, lr = 0.016,
# batch no = 2320 / 2323, train loss = 3.772, lr = 0.016,
# Validation set perplexity : 123.782
# *************************************************
#
# Test set perplexity : 119.839
# Training over
# Epoch 10/20
# batch no = 0 / 2323, train loss = 4.653, lr = 0.009,
# batch no = 232 / 2323, train loss = 3.801, lr = 0.009,
# batch no = 464 / 2323, train loss = 3.946, lr = 0.009,
# batch no = 696 / 2323, train loss = 3.888, lr = 0.009,
# batch no = 928 / 2323, train loss = 3.631, lr = 0.009,
# batch no = 1160 / 2323, train loss = 3.879, lr = 0.009,
# batch no = 1392 / 2323, train loss = 3.882, lr = 0.009,
# batch no = 1624 / 2323, train loss = 3.753, lr = 0.009,
# batch no = 1856 / 2323, train loss = 3.481, lr = 0.009,
# batch no = 2088 / 2323, train loss = 3.794, lr = 0.009,
# batch no = 2320 / 2323, train loss = 3.755, lr = 0.009,
# Validation set perplexity : 123.400
# *************************************************
#
# Test set perplexity : 119.388
# Training over
# Epoch 11/20
# batch no = 0 / 2323, train loss = 4.646, lr = 0.004,
# batch no = 232 / 2323, train loss = 3.789, lr = 0.004,
# batch no = 464 / 2323, train loss = 3.935, lr = 0.004,
# batch no = 696 / 2323, train loss = 3.883, lr = 0.004,
# batch no = 928 / 2323, train loss = 3.622, lr = 0.004,
# batch no = 1160 / 2323, train loss = 3.864, lr = 0.004,
# batch no = 1392 / 2323, train loss = 3.867, lr = 0.004,
# batch no = 1624 / 2323, train loss = 3.743, lr = 0.004,
# batch no = 1856 / 2323, train loss = 3.474, lr = 0.004,
# batch no = 2088 / 2323, train loss = 3.781, lr = 0.004,
# batch no = 2320 / 2323, train loss = 3.747, lr = 0.004,
# Validation set perplexity : 123.151
# *************************************************
#
# Test set perplexity : 119.123
# Training over
# Epoch 12/20
# batch no = 0 / 2323, train loss = 4.642, lr = 0.002,
# batch no = 232 / 2323, train loss = 3.783, lr = 0.002,
# batch no = 464 / 2323, train loss = 3.929, lr = 0.002,
# batch no = 696 / 2323, train loss = 3.880, lr = 0.002,
# batch no = 928 / 2323, train loss = 3.616, lr = 0.002,
# batch no = 1160 / 2323, train loss = 3.857, lr = 0.002,
# batch no = 1392 / 2323, train loss = 3.859, lr = 0.002,
# batch no = 1624 / 2323, train loss = 3.738, lr = 0.002,
# batch no = 1856 / 2323, train loss = 3.471, lr = 0.002,
# batch no = 2088 / 2323, train loss = 3.773, lr = 0.002,
# batch no = 2320 / 2323, train loss = 3.744, lr = 0.002,
# Validation set perplexity : 122.996
# *************************************************
#
# Test set perplexity : 118.962
# Training over
# Epoch 13/20
# batch no = 0 / 2323, train loss = 4.640, lr = 0.001,
# batch no = 232 / 2323, train loss = 3.780, lr = 0.001,
# batch no = 464 / 2323, train loss = 3.925, lr = 0.001,
# batch no = 696 / 2323, train loss = 3.878, lr = 0.001,
# batch no = 928 / 2323, train loss = 3.613, lr = 0.001,
# batch no = 1160 / 2323, train loss = 3.853, lr = 0.001,
# batch no = 1392 / 2323, train loss = 3.855, lr = 0.001,
# batch no = 1624 / 2323, train loss = 3.736, lr = 0.001,
# batch no = 1856 / 2323, train loss = 3.470, lr = 0.001,
# batch no = 2088 / 2323, train loss = 3.769, lr = 0.001,
# batch no = 2320 / 2323, train loss = 3.742, lr = 0.001,
# Validation set perplexity : 122.906
# *************************************************
#
# Test set perplexity : 118.865
# Training over
# Epoch 14/20
# batch no = 0 / 2323, train loss = 4.638, lr = 0.001,
# batch no = 232 / 2323, train loss = 3.779, lr = 0.001,
# batch no = 464 / 2323, train loss = 3.922, lr = 0.001,
# batch no = 696 / 2323, train loss = 3.876, lr = 0.001,
# batch no = 928 / 2323, train loss = 3.611, lr = 0.001,
# batch no = 1160 / 2323, train loss = 3.852, lr = 0.001,
# batch no = 1392 / 2323, train loss = 3.852, lr = 0.001,
# batch no = 1624 / 2323, train loss = 3.734, lr = 0.001,
# batch no = 1856 / 2323, train loss = 3.470, lr = 0.001,
# batch no = 2088 / 2323, train loss = 3.766, lr = 0.001,
# batch no = 2320 / 2323, train loss = 3.741, lr = 0.001,
# Validation set perplexity : 122.865
# *************************************************
#
# Test set perplexity : 118.818
# Training over
# Epoch 15/20
# batch no = 0 / 2323, train loss = 4.637, lr = 0.000,
# batch no = 232 / 2323, train loss = 3.778, lr = 0.000,
# batch no = 464 / 2323, train loss = 3.921, lr = 0.000,
# batch no = 696 / 2323, train loss = 3.875, lr = 0.000,
# batch no = 928 / 2323, train loss = 3.610, lr = 0.000,
# batch no = 1160 / 2323, train loss = 3.851, lr = 0.000,
# batch no = 1392 / 2323, train loss = 3.850, lr = 0.000,
# batch no = 1624 / 2323, train loss = 3.733, lr = 0.000,
# batch no = 1856 / 2323, train loss = 3.470, lr = 0.000,
# batch no = 2088 / 2323, train loss = 3.765, lr = 0.000,
# batch no = 2320 / 2323, train loss = 3.741, lr = 0.000,
# Validation set perplexity : 122.848
# *************************************************
#
# Test set perplexity : 118.799
# Training over
# Epoch 16/20
# batch no = 0 / 2323, train loss = 4.637, lr = 0.000,
# batch no = 232 / 2323, train loss = 3.777, lr = 0.000,
# batch no = 464 / 2323, train loss = 3.920, lr = 0.000,
# batch no = 696 / 2323, train loss = 3.875, lr = 0.000,
# batch no = 928 / 2323, train loss = 3.609, lr = 0.000,
# batch no = 1160 / 2323, train loss = 3.850, lr = 0.000,
# batch no = 1392 / 2323, train loss = 3.849, lr = 0.000,
# batch no = 1624 / 2323, train loss = 3.732, lr = 0.000,
# batch no = 1856 / 2323, train loss = 3.470, lr = 0.000,
# batch no = 2088 / 2323, train loss = 3.765, lr = 0.000,
# batch no = 2320 / 2323, train loss = 3.740, lr = 0.000,
# Validation set perplexity : 122.841
# *************************************************
#
# Test set perplexity : 118.792
# Training over
# Epoch 17/20
# batch no = 0 / 2323, train loss = 4.636, lr = 0.000,
# batch no = 232 / 2323, train loss = 3.777, lr = 0.000,
# batch no = 464 / 2323, train loss = 3.919, lr = 0.000,
# batch no = 696 / 2323, train loss = 3.874, lr = 0.000,
# batch no = 928 / 2323, train loss = 3.609, lr = 0.000,
# batch no = 1160 / 2323, train loss = 3.850, lr = 0.000,
# batch no = 1392 / 2323, train loss = 3.849, lr = 0.000,
# batch no = 1624 / 2323, train loss = 3.732, lr = 0.000,
# batch no = 1856 / 2323, train loss = 3.470, lr = 0.000,
# batch no = 2088 / 2323, train loss = 3.764, lr = 0.000,
# batch no = 2320 / 2323, train loss = 3.740, lr = 0.000,
# Validation set perplexity : 122.838
# *************************************************
#
# Test set perplexity : 118.788
# Training over
# Epoch 18/20
# batch no = 0 / 2323, train loss = 4.636, lr = 0.000,
# batch no = 232 / 2323, train loss = 3.777, lr = 0.000,
# batch no = 464 / 2323, train loss = 3.919, lr = 0.000,
# batch no = 696 / 2323, train loss = 3.874, lr = 0.000,
# batch no = 928 / 2323, train loss = 3.609, lr = 0.000,
# batch no = 1160 / 2323, train loss = 3.850, lr = 0.000,
# batch no = 1392 / 2323, train loss = 3.849, lr = 0.000,
# batch no = 1624 / 2323, train loss = 3.731, lr = 0.000,
# batch no = 1856 / 2323, train loss = 3.470, lr = 0.000,
# batch no = 2088 / 2323, train loss = 3.764, lr = 0.000,
# batch no = 2320 / 2323, train loss = 3.740, lr = 0.000,
# Validation set perplexity : 122.837
# *************************************************
#
# Test set perplexity : 118.787
# Training over
# Epoch 19/20
# batch no = 0 / 2323, train loss = 4.636, lr = 0.000,
# batch no = 232 / 2323, train loss = 3.776, lr = 0.000,
# batch no = 464 / 2323, train loss = 3.919, lr = 0.000,
# batch no = 696 / 2323, train loss = 3.874, lr = 0.000,
# batch no = 928 / 2323, train loss = 3.609, lr = 0.000,
# batch no = 1160 / 2323, train loss = 3.850, lr = 0.000,
# batch no = 1392 / 2323, train loss = 3.848, lr = 0.000,
# batch no = 1624 / 2323, train loss = 3.731, lr = 0.000,
# batch no = 1856 / 2323, train loss = 3.470, lr = 0.000,
# batch no = 2088 / 2323, train loss = 3.764, lr = 0.000,
# batch no = 2320 / 2323, train loss = 3.740, lr = 0.000,
# Validation set perplexity : 122.836
# *************************************************
#
# Test set perplexity : 118.787
# Training over
# Epoch 20/20
# batch no = 0 / 2323, train loss = 4.636, lr = 0.000,
# batch no = 232 / 2323, train loss = 3.776, lr = 0.000,
# batch no = 464 / 2323, train loss = 3.919, lr = 0.000,
# batch no = 696 / 2323, train loss = 3.874, lr = 0.000,
# batch no = 928 / 2323, train loss = 3.608, lr = 0.000,
# batch no = 1160 / 2323, train loss = 3.850, lr = 0.000,
# batch no = 1392 / 2323, train loss = 3.848, lr = 0.000,
# batch no = 1624 / 2323, train loss = 3.731, lr = 0.000,
# batch no = 1856 / 2323, train loss = 3.470, lr = 0.000,
# batch no = 2088 / 2323, train loss = 3.764, lr = 0.000,
# batch no = 2320 / 2323, train loss = 3.740, lr = 0.000,
# Validation set perplexity : 122.836
# *************************************************
#
# Test set perplexity : 118.787
# Training over

# %%
# Running GRU model with 40% dropout
batch_size = 20
seq_length = 20
base = 'gru'

hidden_size = 200
layer_num = 2
dropout = 0.4
w_init = 0.1

model_gru_dropout = Model(words_len, hidden_size, layer_num, dropout, w_init, base) #GRU model 40% dropout
model_gru_dropout.to(device)

num_epochs = 50
epoch_threshold = 15
lr = 0.5
model_name = "GRU_dropout"
lr_factor = 1.2

main((train,validation,test), num_epochs, epoch_threshold, lr, model_gru_dropout, model_name,base, lr_factor, batch_size, seq_length, max_norm)
# Out:
# Epoch 1/50
# batch no = 0 / 2323, train loss = 9.214, lr = 0.500,
# batch no = 232 / 2323, train loss = 6.537, lr = 0.500,
# batch no = 464 / 2323, train loss = 6.132, lr = 0.500,
# batch no = 696 / 2323, train loss = 6.020, lr = 0.500,
# batch no = 928 / 2323, train loss = 5.551, lr = 0.500,
# batch no = 1160 / 2323, train loss = 5.634, lr = 0.500,
# batch no = 1392 / 2323, train loss = 5.716, lr = 0.500,
# batch no = 1624 / 2323, train loss = 5.527, lr = 0.500,
# batch no = 1856 / 2323, train loss = 5.243, lr = 0.500,
# batch no = 2088 / 2323, train loss = 5.806, lr = 0.500,
# batch no = 2320 / 2323, train loss = 5.712, lr = 0.500,
# Validation set perplexity : 220.284
# *************************************************
#
# Test set perplexity : 215.622
# Training over
# Epoch 2/50
# batch no = 0 / 2323, train loss = 6.022, lr = 0.500,
# batch no = 232 / 2323, train loss = 5.407, lr = 0.500,
# batch no = 464 / 2323, train loss = 5.385, lr = 0.500,
# batch no = 696 / 2323, train loss = 5.375, lr = 0.500,
# batch no = 928 / 2323, train loss = 5.081, lr = 0.500,
# batch no = 1160 / 2323, train loss = 5.400, lr = 0.500,
# batch no = 1392 / 2323, train loss = 5.475, lr = 0.500,
# batch no = 1624 / 2323, train loss = 5.318, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.982, lr = 0.500,
# batch no = 2088 / 2323, train loss = 5.492, lr = 0.500,
# batch no = 2320 / 2323, train loss = 5.413, lr = 0.500,
# Validation set perplexity : 178.840
# *************************************************
#
# Test set perplexity : 175.023
# Training over
# Epoch 3/50
# batch no = 0 / 2323, train loss = 5.833, lr = 0.500,
# batch no = 232 / 2323, train loss = 5.164, lr = 0.500,
# batch no = 464 / 2323, train loss = 5.198, lr = 0.500,
# batch no = 696 / 2323, train loss = 5.246, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.907, lr = 0.500,
# batch no = 1160 / 2323, train loss = 5.169, lr = 0.500,
# batch no = 1392 / 2323, train loss = 5.381, lr = 0.500,
# batch no = 1624 / 2323, train loss = 5.059, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.882, lr = 0.500,
# batch no = 2088 / 2323, train loss = 5.359, lr = 0.500,
# batch no = 2320 / 2323, train loss = 5.306, lr = 0.500,
# Validation set perplexity : 160.308
# *************************************************
#
# Test set perplexity : 156.370
# Training over
# Epoch 4/50
# batch no = 0 / 2323, train loss = 5.636, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.961, lr = 0.500,
# batch no = 464 / 2323, train loss = 5.078, lr = 0.500,
# batch no = 696 / 2323, train loss = 5.102, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.852, lr = 0.500,
# batch no = 1160 / 2323, train loss = 5.068, lr = 0.500,
# batch no = 1392 / 2323, train loss = 5.247, lr = 0.500,
# batch no = 1624 / 2323, train loss = 5.078, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.769, lr = 0.500,
# batch no = 2088 / 2323, train loss = 5.182, lr = 0.500,
# batch no = 2320 / 2323, train loss = 5.192, lr = 0.500,
# Validation set perplexity : 148.014
# *************************************************
#
# Test set perplexity : 144.894
# Training over
# Epoch 5/50
# batch no = 0 / 2323, train loss = 5.642, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.907, lr = 0.500,
# batch no = 464 / 2323, train loss = 5.029, lr = 0.500,
# batch no = 696 / 2323, train loss = 5.061, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.813, lr = 0.500,
# batch no = 1160 / 2323, train loss = 5.054, lr = 0.500,
# batch no = 1392 / 2323, train loss = 5.185, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.955, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.677, lr = 0.500,
# batch no = 2088 / 2323, train loss = 5.138, lr = 0.500,
# batch no = 2320 / 2323, train loss = 5.065, lr = 0.500,
# Validation set perplexity : 141.814
# *************************************************
#
# Test set perplexity : 138.686
# Training over
# Epoch 6/50
# batch no = 0 / 2323, train loss = 5.572, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.820, lr = 0.500,
# batch no = 464 / 2323, train loss = 4.942, lr = 0.500,
# batch no = 696 / 2323, train loss = 4.970, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.665, lr = 0.500,
# batch no = 1160 / 2323, train loss = 4.968, lr = 0.500,
# batch no = 1392 / 2323, train loss = 5.088, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.910, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.683, lr = 0.500,
# batch no = 2088 / 2323, train loss = 5.108, lr = 0.500,
# batch no = 2320 / 2323, train loss = 5.077, lr = 0.500,
# Validation set perplexity : 135.848
# *************************************************
#
# Test set perplexity : 132.907
# Training over
# Epoch 7/50
# batch no = 0 / 2323, train loss = 5.579, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.737, lr = 0.500,
# batch no = 464 / 2323, train loss = 4.872, lr = 0.500,
# batch no = 696 / 2323, train loss = 4.904, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.656, lr = 0.500,
# batch no = 1160 / 2323, train loss = 4.929, lr = 0.500,
# batch no = 1392 / 2323, train loss = 5.112, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.904, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.602, lr = 0.500,
# batch no = 2088 / 2323, train loss = 5.008, lr = 0.500,
# batch no = 2320 / 2323, train loss = 4.864, lr = 0.500,
# Validation set perplexity : 135.353
# *************************************************
#
# Test set perplexity : 132.491
# Training over
# Epoch 8/50
# batch no = 0 / 2323, train loss = 5.552, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.778, lr = 0.500,
# batch no = 464 / 2323, train loss = 4.900, lr = 0.500,
# batch no = 696 / 2323, train loss = 4.825, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.681, lr = 0.500,
# batch no = 1160 / 2323, train loss = 4.893, lr = 0.500,
# batch no = 1392 / 2323, train loss = 5.006, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.871, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.576, lr = 0.500,
# batch no = 2088 / 2323, train loss = 5.081, lr = 0.500,
# batch no = 2320 / 2323, train loss = 4.962, lr = 0.500,
# Validation set perplexity : 131.340
# *************************************************
#
# Test set perplexity : 128.432
# Training over
# Epoch 9/50
# batch no = 0 / 2323, train loss = 5.453, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.697, lr = 0.500,
# batch no = 464 / 2323, train loss = 4.818, lr = 0.500,
# batch no = 696 / 2323, train loss = 4.762, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.638, lr = 0.500,
# batch no = 1160 / 2323, train loss = 4.954, lr = 0.500,
# batch no = 1392 / 2323, train loss = 5.046, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.815, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.503, lr = 0.500,
# batch no = 2088 / 2323, train loss = 4.846, lr = 0.500,
# batch no = 2320 / 2323, train loss = 4.832, lr = 0.500,
# Validation set perplexity : 126.394
# *************************************************
#
# Test set perplexity : 123.656
# Training over
# Epoch 10/50
# batch no = 0 / 2323, train loss = 5.536, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.730, lr = 0.500,
# batch no = 464 / 2323, train loss = 4.742, lr = 0.500,
# batch no = 696 / 2323, train loss = 4.804, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.625, lr = 0.500,
# batch no = 1160 / 2323, train loss = 4.842, lr = 0.500,
# batch no = 1392 / 2323, train loss = 5.014, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.843, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.428, lr = 0.500,
# batch no = 2088 / 2323, train loss = 4.899, lr = 0.500,
# batch no = 2320 / 2323, train loss = 4.826, lr = 0.500,
# Validation set perplexity : 127.792
# *************************************************
#
# Test set perplexity : 124.707
# Training over
# Epoch 11/50
# batch no = 0 / 2323, train loss = 5.470, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.653, lr = 0.500,
# batch no = 464 / 2323, train loss = 4.778, lr = 0.500,
# batch no = 696 / 2323, train loss = 4.721, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.575, lr = 0.500,
# batch no = 1160 / 2323, train loss = 4.838, lr = 0.500,
# batch no = 1392 / 2323, train loss = 4.985, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.749, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.462, lr = 0.500,
# batch no = 2088 / 2323, train loss = 4.889, lr = 0.500,
# batch no = 2320 / 2323, train loss = 4.816, lr = 0.500,
# Validation set perplexity : 126.538
# *************************************************
#
# Test set perplexity : 123.577
# Training over
# Epoch 12/50
# batch no = 0 / 2323, train loss = 5.436, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.679, lr = 0.500,
# batch no = 464 / 2323, train loss = 4.687, lr = 0.500,
# batch no = 696 / 2323, train loss = 4.720, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.674, lr = 0.500,
# batch no = 1160 / 2323, train loss = 4.844, lr = 0.500,
# batch no = 1392 / 2323, train loss = 4.933, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.762, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.482, lr = 0.500,
# batch no = 2088 / 2323, train loss = 4.958, lr = 0.500,
# batch no = 2320 / 2323, train loss = 4.754, lr = 0.500,
# Validation set perplexity : 123.790
# *************************************************
#
# Test set perplexity : 120.942
# Training over
# Epoch 13/50
# batch no = 0 / 2323, train loss = 5.430, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.612, lr = 0.500,
# batch no = 464 / 2323, train loss = 4.732, lr = 0.500,
# batch no = 696 / 2323, train loss = 4.760, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.555, lr = 0.500,
# batch no = 1160 / 2323, train loss = 4.840, lr = 0.500,
# batch no = 1392 / 2323, train loss = 4.836, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.796, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.365, lr = 0.500,
# batch no = 2088 / 2323, train loss = 4.961, lr = 0.500,
# batch no = 2320 / 2323, train loss = 4.737, lr = 0.500,
# Validation set perplexity : 122.008
# *************************************************
#
# Test set perplexity : 119.552
# Training over
# Epoch 14/50
# batch no = 0 / 2323, train loss = 5.431, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.548, lr = 0.500,
# batch no = 464 / 2323, train loss = 4.658, lr = 0.500,
# batch no = 696 / 2323, train loss = 4.636, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.625, lr = 0.500,
# batch no = 1160 / 2323, train loss = 4.817, lr = 0.500,
# batch no = 1392 / 2323, train loss = 4.887, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.789, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.382, lr = 0.500,
# batch no = 2088 / 2323, train loss = 4.878, lr = 0.500,
# batch no = 2320 / 2323, train loss = 4.838, lr = 0.500,
# Validation set perplexity : 122.024
# *************************************************
#
# Test set perplexity : 119.333
# Training over
# Epoch 15/50
# batch no = 0 / 2323, train loss = 5.407, lr = 0.500,
# batch no = 232 / 2323, train loss = 4.563, lr = 0.500,
# batch no = 464 / 2323, train loss = 4.563, lr = 0.500,
# batch no = 696 / 2323, train loss = 4.746, lr = 0.500,
# batch no = 928 / 2323, train loss = 4.601, lr = 0.500,
# batch no = 1160 / 2323, train loss = 4.768, lr = 0.500,
# batch no = 1392 / 2323, train loss = 4.940, lr = 0.500,
# batch no = 1624 / 2323, train loss = 4.665, lr = 0.500,
# batch no = 1856 / 2323, train loss = 4.446, lr = 0.500,
# batch no = 2088 / 2323, train loss = 4.800, lr = 0.500,
# batch no = 2320 / 2323, train loss = 4.789, lr = 0.500,
# Validation set perplexity : 121.292
# *************************************************
#
# Test set perplexity : 118.433
# Training over
# Epoch 16/50
# batch no = 0 / 2323, train loss = 5.472, lr = 0.417,
# batch no = 232 / 2323, train loss = 4.508, lr = 0.417,
# batch no = 464 / 2323, train loss = 4.620, lr = 0.417,
# batch no = 696 / 2323, train loss = 4.659, lr = 0.417,
# batch no = 928 / 2323, train loss = 4.509, lr = 0.417,
# batch no = 1160 / 2323, train loss = 4.769, lr = 0.417,
# batch no = 1392 / 2323, train loss = 4.741, lr = 0.417,
# batch no = 1624 / 2323, train loss = 4.639, lr = 0.417,
# batch no = 1856 / 2323, train loss = 4.295, lr = 0.417,
# batch no = 2088 / 2323, train loss = 4.738, lr = 0.417,
# batch no = 2320 / 2323, train loss = 4.731, lr = 0.417,
# Validation set perplexity : 117.434
# *************************************************
#
# Test set perplexity : 114.127
# Training over
# Epoch 17/50
# batch no = 0 / 2323, train loss = 5.304, lr = 0.347,
# batch no = 232 / 2323, train loss = 4.546, lr = 0.347,
# batch no = 464 / 2323, train loss = 4.541, lr = 0.347,
# batch no = 696 / 2323, train loss = 4.606, lr = 0.347,
# batch no = 928 / 2323, train loss = 4.486, lr = 0.347,
# batch no = 1160 / 2323, train loss = 4.655, lr = 0.347,
# batch no = 1392 / 2323, train loss = 4.793, lr = 0.347,
# batch no = 1624 / 2323, train loss = 4.612, lr = 0.347,
# batch no = 1856 / 2323, train loss = 4.323, lr = 0.347,
# batch no = 2088 / 2323, train loss = 4.763, lr = 0.347,
# batch no = 2320 / 2323, train loss = 4.699, lr = 0.347,
# Validation set perplexity : 115.294
# *************************************************
#
# Test set perplexity : 111.968
# Training over
# Epoch 18/50
# batch no = 0 / 2323, train loss = 5.337, lr = 0.289,
# batch no = 232 / 2323, train loss = 4.486, lr = 0.289,
# batch no = 464 / 2323, train loss = 4.546, lr = 0.289,
# batch no = 696 / 2323, train loss = 4.560, lr = 0.289,
# batch no = 928 / 2323, train loss = 4.441, lr = 0.289,
# batch no = 1160 / 2323, train loss = 4.658, lr = 0.289,
# batch no = 1392 / 2323, train loss = 4.694, lr = 0.289,
# batch no = 1624 / 2323, train loss = 4.592, lr = 0.289,
# batch no = 1856 / 2323, train loss = 4.264, lr = 0.289,
# batch no = 2088 / 2323, train loss = 4.660, lr = 0.289,
# batch no = 2320 / 2323, train loss = 4.627, lr = 0.289,
# Validation set perplexity : 112.065
# *************************************************
#
# Test set perplexity : 109.338
# Training over
# Epoch 19/50
# batch no = 0 / 2323, train loss = 5.215, lr = 0.241,
# batch no = 232 / 2323, train loss = 4.419, lr = 0.241,
# batch no = 464 / 2323, train loss = 4.523, lr = 0.241,
# batch no = 696 / 2323, train loss = 4.529, lr = 0.241,
# batch no = 928 / 2323, train loss = 4.424, lr = 0.241,
# batch no = 1160 / 2323, train loss = 4.566, lr = 0.241,
# batch no = 1392 / 2323, train loss = 4.613, lr = 0.241,
# batch no = 1624 / 2323, train loss = 4.498, lr = 0.241,
# batch no = 1856 / 2323, train loss = 4.230, lr = 0.241,
# batch no = 2088 / 2323, train loss = 4.628, lr = 0.241,
# batch no = 2320 / 2323, train loss = 4.535, lr = 0.241,
# Validation set perplexity : 110.041
# *************************************************
#
# Test set perplexity : 106.571
# Training over
# Epoch 20/50
# batch no = 0 / 2323, train loss = 5.271, lr = 0.201,
# batch no = 232 / 2323, train loss = 4.397, lr = 0.201,
# batch no = 464 / 2323, train loss = 4.431, lr = 0.201,
# batch no = 696 / 2323, train loss = 4.495, lr = 0.201,
# batch no = 928 / 2323, train loss = 4.378, lr = 0.201,
# batch no = 1160 / 2323, train loss = 4.553, lr = 0.201,
# batch no = 1392 / 2323, train loss = 4.668, lr = 0.201,
# batch no = 1624 / 2323, train loss = 4.508, lr = 0.201,
# batch no = 1856 / 2323, train loss = 4.175, lr = 0.201,
# batch no = 2088 / 2323, train loss = 4.560, lr = 0.201,
# batch no = 2320 / 2323, train loss = 4.568, lr = 0.201,
# Validation set perplexity : 107.904
# *************************************************
#
# Test set perplexity : 104.339
# Training over
# Epoch 21/50
# batch no = 0 / 2323, train loss = 5.190, lr = 0.167,
# batch no = 232 / 2323, train loss = 4.369, lr = 0.167,
# batch no = 464 / 2323, train loss = 4.489, lr = 0.167,
# batch no = 696 / 2323, train loss = 4.345, lr = 0.167,
# batch no = 928 / 2323, train loss = 4.330, lr = 0.167,
# batch no = 1160 / 2323, train loss = 4.590, lr = 0.167,
# batch no = 1392 / 2323, train loss = 4.583, lr = 0.167,
# batch no = 1624 / 2323, train loss = 4.455, lr = 0.167,
# batch no = 1856 / 2323, train loss = 4.209, lr = 0.167,
# batch no = 2088 / 2323, train loss = 4.552, lr = 0.167,
# batch no = 2320 / 2323, train loss = 4.461, lr = 0.167,
# Validation set perplexity : 106.855
# *************************************************
#
# Test set perplexity : 103.102
# Training over
# Epoch 22/50
# batch no = 0 / 2323, train loss = 5.136, lr = 0.140,
# batch no = 232 / 2323, train loss = 4.307, lr = 0.140,
# batch no = 464 / 2323, train loss = 4.352, lr = 0.140,
# batch no = 696 / 2323, train loss = 4.421, lr = 0.140,
# batch no = 928 / 2323, train loss = 4.220, lr = 0.140,
# batch no = 1160 / 2323, train loss = 4.586, lr = 0.140,
# batch no = 1392 / 2323, train loss = 4.560, lr = 0.140,
# batch no = 1624 / 2323, train loss = 4.436, lr = 0.140,
# batch no = 1856 / 2323, train loss = 4.211, lr = 0.140,
# batch no = 2088 / 2323, train loss = 4.438, lr = 0.140,
# batch no = 2320 / 2323, train loss = 4.502, lr = 0.140,
# Validation set perplexity : 105.440
# *************************************************
#
# Test set perplexity : 101.892
# Training over
# Epoch 23/50
# batch no = 0 / 2323, train loss = 5.152, lr = 0.116,
# batch no = 232 / 2323, train loss = 4.297, lr = 0.116,
# batch no = 464 / 2323, train loss = 4.387, lr = 0.116,
# batch no = 696 / 2323, train loss = 4.377, lr = 0.116,
# batch no = 928 / 2323, train loss = 4.302, lr = 0.116,
# batch no = 1160 / 2323, train loss = 4.569, lr = 0.116,
# batch no = 1392 / 2323, train loss = 4.531, lr = 0.116,
# batch no = 1624 / 2323, train loss = 4.448, lr = 0.116,
# batch no = 1856 / 2323, train loss = 4.101, lr = 0.116,
# batch no = 2088 / 2323, train loss = 4.492, lr = 0.116,
# batch no = 2320 / 2323, train loss = 4.597, lr = 0.116,
# Validation set perplexity : 104.043
# *************************************************
#
# Test set perplexity : 100.616
# Training over
# Epoch 24/50
# batch no = 0 / 2323, train loss = 5.118, lr = 0.097,
# batch no = 232 / 2323, train loss = 4.194, lr = 0.097,
# batch no = 464 / 2323, train loss = 4.350, lr = 0.097,
# batch no = 696 / 2323, train loss = 4.436, lr = 0.097,
# batch no = 928 / 2323, train loss = 4.273, lr = 0.097,
# batch no = 1160 / 2323, train loss = 4.565, lr = 0.097,
# batch no = 1392 / 2323, train loss = 4.532, lr = 0.097,
# batch no = 1624 / 2323, train loss = 4.472, lr = 0.097,
# batch no = 1856 / 2323, train loss = 4.131, lr = 0.097,
# batch no = 2088 / 2323, train loss = 4.410, lr = 0.097,
# batch no = 2320 / 2323, train loss = 4.475, lr = 0.097,
# Validation set perplexity : 103.374
# *************************************************
#
# Test set perplexity : 99.913
# Training over
# Epoch 25/50
# batch no = 0 / 2323, train loss = 5.152, lr = 0.081,
# batch no = 232 / 2323, train loss = 4.346, lr = 0.081,
# batch no = 464 / 2323, train loss = 4.320, lr = 0.081,
# batch no = 696 / 2323, train loss = 4.333, lr = 0.081,
# batch no = 928 / 2323, train loss = 4.232, lr = 0.081,
# batch no = 1160 / 2323, train loss = 4.486, lr = 0.081,
# batch no = 1392 / 2323, train loss = 4.419, lr = 0.081,
# batch no = 1624 / 2323, train loss = 4.382, lr = 0.081,
# batch no = 1856 / 2323, train loss = 4.113, lr = 0.081,
# batch no = 2088 / 2323, train loss = 4.464, lr = 0.081,
# batch no = 2320 / 2323, train loss = 4.508, lr = 0.081,
# Validation set perplexity : 102.483
# *************************************************
#
# Test set perplexity : 99.261
# Training over
# Epoch 26/50
# batch no = 0 / 2323, train loss = 5.198, lr = 0.067,
# batch no = 232 / 2323, train loss = 4.255, lr = 0.067,
# batch no = 464 / 2323, train loss = 4.312, lr = 0.067,
# batch no = 696 / 2323, train loss = 4.348, lr = 0.067,
# batch no = 928 / 2323, train loss = 4.232, lr = 0.067,
# batch no = 1160 / 2323, train loss = 4.464, lr = 0.067,
# batch no = 1392 / 2323, train loss = 4.536, lr = 0.067,
# batch no = 1624 / 2323, train loss = 4.360, lr = 0.067,
# batch no = 1856 / 2323, train loss = 4.060, lr = 0.067,
# batch no = 2088 / 2323, train loss = 4.518, lr = 0.067,
# batch no = 2320 / 2323, train loss = 4.454, lr = 0.067,
# Validation set perplexity : 102.160
# *************************************************
#
# Test set perplexity : 98.598
# Training over
# Epoch 27/50
# batch no = 0 / 2323, train loss = 5.059, lr = 0.056,
# batch no = 232 / 2323, train loss = 4.198, lr = 0.056,
# batch no = 464 / 2323, train loss = 4.267, lr = 0.056,
# batch no = 696 / 2323, train loss = 4.312, lr = 0.056,
# batch no = 928 / 2323, train loss = 4.214, lr = 0.056,
# batch no = 1160 / 2323, train loss = 4.587, lr = 0.056,
# batch no = 1392 / 2323, train loss = 4.506, lr = 0.056,
# batch no = 1624 / 2323, train loss = 4.390, lr = 0.056,
# batch no = 1856 / 2323, train loss = 4.009, lr = 0.056,
# batch no = 2088 / 2323, train loss = 4.496, lr = 0.056,
# batch no = 2320 / 2323, train loss = 4.401, lr = 0.056,
# Validation set perplexity : 101.468
# *************************************************
#
# Test set perplexity : 98.167
# Training over
# Epoch 28/50
# batch no = 0 / 2323, train loss = 5.087, lr = 0.047,
# batch no = 232 / 2323, train loss = 4.151, lr = 0.047,
# batch no = 464 / 2323, train loss = 4.330, lr = 0.047,
# batch no = 696 / 2323, train loss = 4.384, lr = 0.047,
# batch no = 928 / 2323, train loss = 4.167, lr = 0.047,
# batch no = 1160 / 2323, train loss = 4.398, lr = 0.047,
# batch no = 1392 / 2323, train loss = 4.515, lr = 0.047,
# batch no = 1624 / 2323, train loss = 4.441, lr = 0.047,
# batch no = 1856 / 2323, train loss = 4.076, lr = 0.047,
# batch no = 2088 / 2323, train loss = 4.477, lr = 0.047,
# batch no = 2320 / 2323, train loss = 4.395, lr = 0.047,
# Validation set perplexity : 101.130
# *************************************************
#
# Test set perplexity : 97.752
# Training over
# Epoch 29/50
# batch no = 0 / 2323, train loss = 5.114, lr = 0.039,
# batch no = 232 / 2323, train loss = 4.259, lr = 0.039,
# batch no = 464 / 2323, train loss = 4.334, lr = 0.039,
# batch no = 696 / 2323, train loss = 4.303, lr = 0.039,
# batch no = 928 / 2323, train loss = 4.134, lr = 0.039,
# batch no = 1160 / 2323, train loss = 4.482, lr = 0.039,
# batch no = 1392 / 2323, train loss = 4.544, lr = 0.039,
# batch no = 1624 / 2323, train loss = 4.286, lr = 0.039,
# batch no = 1856 / 2323, train loss = 4.061, lr = 0.039,
# batch no = 2088 / 2323, train loss = 4.465, lr = 0.039,
# batch no = 2320 / 2323, train loss = 4.448, lr = 0.039,
# Validation set perplexity : 100.766
# *************************************************
#
# Test set perplexity : 97.300
# Training over
# Epoch 30/50
# batch no = 0 / 2323, train loss = 5.131, lr = 0.032,
# batch no = 232 / 2323, train loss = 4.308, lr = 0.032,
# batch no = 464 / 2323, train loss = 4.346, lr = 0.032,
# batch no = 696 / 2323, train loss = 4.335, lr = 0.032,
# batch no = 928 / 2323, train loss = 4.147, lr = 0.032,
# batch no = 1160 / 2323, train loss = 4.555, lr = 0.032,
# batch no = 1392 / 2323, train loss = 4.536, lr = 0.032,
# batch no = 1624 / 2323, train loss = 4.341, lr = 0.032,
# batch no = 1856 / 2323, train loss = 4.068, lr = 0.032,
# batch no = 2088 / 2323, train loss = 4.433, lr = 0.032,
# batch no = 2320 / 2323, train loss = 4.408, lr = 0.032,
# Validation set perplexity : 100.425
# *************************************************
#
# Test set perplexity : 97.062
# Training over
# Epoch 31/50
# batch no = 0 / 2323, train loss = 5.152, lr = 0.027,
# batch no = 232 / 2323, train loss = 4.141, lr = 0.027,
# batch no = 464 / 2323, train loss = 4.343, lr = 0.027,
# batch no = 696 / 2323, train loss = 4.206, lr = 0.027,
# batch no = 928 / 2323, train loss = 4.134, lr = 0.027,
# batch no = 1160 / 2323, train loss = 4.398, lr = 0.027,
# batch no = 1392 / 2323, train loss = 4.507, lr = 0.027,
# batch no = 1624 / 2323, train loss = 4.355, lr = 0.027,
# batch no = 1856 / 2323, train loss = 4.007, lr = 0.027,
# batch no = 2088 / 2323, train loss = 4.353, lr = 0.027,
# batch no = 2320 / 2323, train loss = 4.438, lr = 0.027,
# Validation set perplexity : 100.266
# *************************************************
#
# Test set perplexity : 96.839
# Training over
# Epoch 32/50
# batch no = 0 / 2323, train loss = 5.085, lr = 0.023,
# batch no = 232 / 2323, train loss = 4.302, lr = 0.023,
# batch no = 464 / 2323, train loss = 4.310, lr = 0.023,
# batch no = 696 / 2323, train loss = 4.290, lr = 0.023,
# batch no = 928 / 2323, train loss = 4.165, lr = 0.023,
# batch no = 1160 / 2323, train loss = 4.379, lr = 0.023,
# batch no = 1392 / 2323, train loss = 4.519, lr = 0.023,
# batch no = 1624 / 2323, train loss = 4.350, lr = 0.023,
# batch no = 1856 / 2323, train loss = 4.081, lr = 0.023,
# batch no = 2088 / 2323, train loss = 4.479, lr = 0.023,
# batch no = 2320 / 2323, train loss = 4.431, lr = 0.023,
# Validation set perplexity : 99.999
# *************************************************
#
# Test set perplexity : 96.649
# Training over
# Epoch 33/50
# batch no = 0 / 2323, train loss = 5.098, lr = 0.019,
# batch no = 232 / 2323, train loss = 4.230, lr = 0.019,
# batch no = 464 / 2323, train loss = 4.384, lr = 0.019,
# batch no = 696 / 2323, train loss = 4.344, lr = 0.019,
# batch no = 928 / 2323, train loss = 4.191, lr = 0.019,
# batch no = 1160 / 2323, train loss = 4.405, lr = 0.019,
# batch no = 1392 / 2323, train loss = 4.469, lr = 0.019,
# batch no = 1624 / 2323, train loss = 4.325, lr = 0.019,
# batch no = 1856 / 2323, train loss = 4.049, lr = 0.019,
# batch no = 2088 / 2323, train loss = 4.388, lr = 0.019,
# batch no = 2320 / 2323, train loss = 4.411, lr = 0.019,
# Validation set perplexity : 99.896
# *************************************************
#
# Test set perplexity : 96.600
# Training over
# Epoch 34/50
# batch no = 0 / 2323, train loss = 5.164, lr = 0.016,
# batch no = 232 / 2323, train loss = 4.214, lr = 0.016,
# batch no = 464 / 2323, train loss = 4.234, lr = 0.016,
# batch no = 696 / 2323, train loss = 4.354, lr = 0.016,
# batch no = 928 / 2323, train loss = 4.182, lr = 0.016,
# batch no = 1160 / 2323, train loss = 4.422, lr = 0.016,
# batch no = 1392 / 2323, train loss = 4.450, lr = 0.016,
# batch no = 1624 / 2323, train loss = 4.409, lr = 0.016,
# batch no = 1856 / 2323, train loss = 4.071, lr = 0.016,
# batch no = 2088 / 2323, train loss = 4.355, lr = 0.016,
# batch no = 2320 / 2323, train loss = 4.402, lr = 0.016,
# Validation set perplexity : 99.745
# *************************************************
#
# Test set perplexity : 96.402
# Training over
# Epoch 35/50
# batch no = 0 / 2323, train loss = 5.095, lr = 0.013,
# batch no = 232 / 2323, train loss = 4.218, lr = 0.013,
# batch no = 464 / 2323, train loss = 4.241, lr = 0.013,
# batch no = 696 / 2323, train loss = 4.384, lr = 0.013,
# batch no = 928 / 2323, train loss = 4.134, lr = 0.013,
# batch no = 1160 / 2323, train loss = 4.444, lr = 0.013,
# batch no = 1392 / 2323, train loss = 4.517, lr = 0.013,
# batch no = 1624 / 2323, train loss = 4.428, lr = 0.013,
# batch no = 1856 / 2323, train loss = 4.053, lr = 0.013,
# batch no = 2088 / 2323, train loss = 4.426, lr = 0.013,
# batch no = 2320 / 2323, train loss = 4.386, lr = 0.013,
# Validation set perplexity : 99.634
# *************************************************
#
# Test set perplexity : 96.377
# Training over
# Epoch 36/50
# batch no = 0 / 2323, train loss = 5.154, lr = 0.011,
# batch no = 232 / 2323, train loss = 4.233, lr = 0.011,
# batch no = 464 / 2323, train loss = 4.194, lr = 0.011,
# batch no = 696 / 2323, train loss = 4.315, lr = 0.011,
# batch no = 928 / 2323, train loss = 4.150, lr = 0.011,
# batch no = 1160 / 2323, train loss = 4.418, lr = 0.011,
# batch no = 1392 / 2323, train loss = 4.505, lr = 0.011,
# batch no = 1624 / 2323, train loss = 4.365, lr = 0.011,
# batch no = 1856 / 2323, train loss = 4.035, lr = 0.011,
# batch no = 2088 / 2323, train loss = 4.343, lr = 0.011,
# batch no = 2320 / 2323, train loss = 4.402, lr = 0.011,
# Validation set perplexity : 99.505
# *************************************************
#
# Test set perplexity : 96.147
# Training over
# Epoch 37/50
# batch no = 0 / 2323, train loss = 5.115, lr = 0.009,
# batch no = 232 / 2323, train loss = 4.245, lr = 0.009,
# batch no = 464 / 2323, train loss = 4.311, lr = 0.009,
# batch no = 696 / 2323, train loss = 4.255, lr = 0.009,
# batch no = 928 / 2323, train loss = 4.168, lr = 0.009,
# batch no = 1160 / 2323, train loss = 4.374, lr = 0.009,
# batch no = 1392 / 2323, train loss = 4.541, lr = 0.009,
# batch no = 1624 / 2323, train loss = 4.321, lr = 0.009,
# batch no = 1856 / 2323, train loss = 4.063, lr = 0.009,
# batch no = 2088 / 2323, train loss = 4.450, lr = 0.009,
# batch no = 2320 / 2323, train loss = 4.380, lr = 0.009,
# Validation set perplexity : 99.447
# *************************************************
#
# Test set perplexity : 96.121
# Training over
# Epoch 38/50
# batch no = 0 / 2323, train loss = 5.141, lr = 0.008,
# batch no = 232 / 2323, train loss = 4.308, lr = 0.008,
# batch no = 464 / 2323, train loss = 4.239, lr = 0.008,
# batch no = 696 / 2323, train loss = 4.276, lr = 0.008,
# batch no = 928 / 2323, train loss = 4.126, lr = 0.008,
# batch no = 1160 / 2323, train loss = 4.374, lr = 0.008,
# batch no = 1392 / 2323, train loss = 4.468, lr = 0.008,
# batch no = 1624 / 2323, train loss = 4.376, lr = 0.008,
# batch no = 1856 / 2323, train loss = 4.019, lr = 0.008,
# batch no = 2088 / 2323, train loss = 4.493, lr = 0.008,
# batch no = 2320 / 2323, train loss = 4.346, lr = 0.008,
# Validation set perplexity : 99.367
# *************************************************
#
# Test set perplexity : 96.004
# Training over
# Epoch 39/50
# batch no = 0 / 2323, train loss = 5.183, lr = 0.006,
# batch no = 232 / 2323, train loss = 4.154, lr = 0.006,
# batch no = 464 / 2323, train loss = 4.291, lr = 0.006,
# batch no = 696 / 2323, train loss = 4.276, lr = 0.006,
# batch no = 928 / 2323, train loss = 4.185, lr = 0.006,
# batch no = 1160 / 2323, train loss = 4.469, lr = 0.006,
# batch no = 1392 / 2323, train loss = 4.429, lr = 0.006,
# batch no = 1624 / 2323, train loss = 4.319, lr = 0.006,
# batch no = 1856 / 2323, train loss = 4.033, lr = 0.006,
# batch no = 2088 / 2323, train loss = 4.426, lr = 0.006,
# batch no = 2320 / 2323, train loss = 4.441, lr = 0.006,
# Validation set perplexity : 99.329
# *************************************************
#
# Test set perplexity : 95.951
# Training over
# Epoch 40/50
# batch no = 0 / 2323, train loss = 5.103, lr = 0.005,
# batch no = 232 / 2323, train loss = 4.198, lr = 0.005,
# batch no = 464 / 2323, train loss = 4.290, lr = 0.005,
# batch no = 696 / 2323, train loss = 4.301, lr = 0.005,
# batch no = 928 / 2323, train loss = 4.134, lr = 0.005,
# batch no = 1160 / 2323, train loss = 4.433, lr = 0.005,
# batch no = 1392 / 2323, train loss = 4.353, lr = 0.005,
# batch no = 1624 / 2323, train loss = 4.370, lr = 0.005,
# batch no = 1856 / 2323, train loss = 4.117, lr = 0.005,
# batch no = 2088 / 2323, train loss = 4.375, lr = 0.005,
# batch no = 2320 / 2323, train loss = 4.442, lr = 0.005,
# Validation set perplexity : 99.285
# *************************************************
#
# Test set perplexity : 95.903
# Training over
# Epoch 41/50
# batch no = 0 / 2323, train loss = 5.090, lr = 0.004,
# batch no = 232 / 2323, train loss = 4.187, lr = 0.004,
# batch no = 464 / 2323, train loss = 4.294, lr = 0.004,
# batch no = 696 / 2323, train loss = 4.263, lr = 0.004,
# batch no = 928 / 2323, train loss = 4.138, lr = 0.004,
# batch no = 1160 / 2323, train loss = 4.390, lr = 0.004,
# batch no = 1392 / 2323, train loss = 4.423, lr = 0.004,
# batch no = 1624 / 2323, train loss = 4.327, lr = 0.004,
# batch no = 1856 / 2323, train loss = 4.036, lr = 0.004,
# batch no = 2088 / 2323, train loss = 4.383, lr = 0.004,
# batch no = 2320 / 2323, train loss = 4.405, lr = 0.004,
# Validation set perplexity : 99.195
# *************************************************
#
# Test set perplexity : 95.831
# Training over
# Epoch 42/50
# batch no = 0 / 2323, train loss = 5.068, lr = 0.004,
# batch no = 232 / 2323, train loss = 4.143, lr = 0.004,
# batch no = 464 / 2323, train loss = 4.292, lr = 0.004,
# batch no = 696 / 2323, train loss = 4.237, lr = 0.004,
# batch no = 928 / 2323, train loss = 4.210, lr = 0.004,
# batch no = 1160 / 2323, train loss = 4.348, lr = 0.004,
# batch no = 1392 / 2323, train loss = 4.468, lr = 0.004,
# batch no = 1624 / 2323, train loss = 4.291, lr = 0.004,
# batch no = 1856 / 2323, train loss = 4.129, lr = 0.004,
# batch no = 2088 / 2323, train loss = 4.383, lr = 0.004,
# batch no = 2320 / 2323, train loss = 4.377, lr = 0.004,
# Validation set perplexity : 99.128
# *************************************************
#
# Test set perplexity : 95.742
# Training over
# Epoch 43/50
# batch no = 0 / 2323, train loss = 5.111, lr = 0.003,
# batch no = 232 / 2323, train loss = 4.242, lr = 0.003,
# batch no = 464 / 2323, train loss = 4.262, lr = 0.003,
# batch no = 696 / 2323, train loss = 4.255, lr = 0.003,
# batch no = 928 / 2323, train loss = 4.209, lr = 0.003,
# batch no = 1160 / 2323, train loss = 4.518, lr = 0.003,
# batch no = 1392 / 2323, train loss = 4.406, lr = 0.003,
# batch no = 1624 / 2323, train loss = 4.359, lr = 0.003,
# batch no = 1856 / 2323, train loss = 4.063, lr = 0.003,
# batch no = 2088 / 2323, train loss = 4.412, lr = 0.003,
# batch no = 2320 / 2323, train loss = 4.338, lr = 0.003,
# Validation set perplexity : 99.135
# *************************************************
#
# Test set perplexity : 95.750
# Training over
# Epoch 44/50
# batch no = 0 / 2323, train loss = 5.094, lr = 0.003,
# batch no = 232 / 2323, train loss = 4.198, lr = 0.003,
# batch no = 464 / 2323, train loss = 4.338, lr = 0.003,
# batch no = 696 / 2323, train loss = 4.244, lr = 0.003,
# batch no = 928 / 2323, train loss = 4.214, lr = 0.003,
# batch no = 1160 / 2323, train loss = 4.454, lr = 0.003,
# batch no = 1392 / 2323, train loss = 4.491, lr = 0.003,
# batch no = 1624 / 2323, train loss = 4.341, lr = 0.003,
# batch no = 1856 / 2323, train loss = 4.028, lr = 0.003,
# batch no = 2088 / 2323, train loss = 4.398, lr = 0.003,
# batch no = 2320 / 2323, train loss = 4.399, lr = 0.003,
# Validation set perplexity : 99.129
# *************************************************
#
# Test set perplexity : 95.719
# Training over
# Epoch 45/50
# batch no = 0 / 2323, train loss = 5.122, lr = 0.002,
# batch no = 232 / 2323, train loss = 4.325, lr = 0.002,
# batch no = 464 / 2323, train loss = 4.209, lr = 0.002,
# batch no = 696 / 2323, train loss = 4.270, lr = 0.002,
# batch no = 928 / 2323, train loss = 4.173, lr = 0.002,
# batch no = 1160 / 2323, train loss = 4.384, lr = 0.002,
# batch no = 1392 / 2323, train loss = 4.464, lr = 0.002,
# batch no = 1624 / 2323, train loss = 4.326, lr = 0.002,
# batch no = 1856 / 2323, train loss = 4.047, lr = 0.002,
# batch no = 2088 / 2323, train loss = 4.398, lr = 0.002,
# batch no = 2320 / 2323, train loss = 4.388, lr = 0.002,
# Validation set perplexity : 99.097
# *************************************************
#
# Test set perplexity : 95.674
# Training over
# Epoch 46/50
# batch no = 0 / 2323, train loss = 5.064, lr = 0.002,
# batch no = 232 / 2323, train loss = 4.250, lr = 0.002,
# batch no = 464 / 2323, train loss = 4.320, lr = 0.002,
# batch no = 696 / 2323, train loss = 4.274, lr = 0.002,
# batch no = 928 / 2323, train loss = 4.168, lr = 0.002,
# batch no = 1160 / 2323, train loss = 4.471, lr = 0.002,
# batch no = 1392 / 2323, train loss = 4.410, lr = 0.002,
# batch no = 1624 / 2323, train loss = 4.309, lr = 0.002,
# batch no = 1856 / 2323, train loss = 4.030, lr = 0.002,
# batch no = 2088 / 2323, train loss = 4.417, lr = 0.002,
# batch no = 2320 / 2323, train loss = 4.346, lr = 0.002,
# Validation set perplexity : 99.089
# *************************************************
#
# Test set perplexity : 95.662
# Training over
# Epoch 47/50
# batch no = 0 / 2323, train loss = 5.135, lr = 0.001,
# batch no = 232 / 2323, train loss = 4.152, lr = 0.001,
# batch no = 464 / 2323, train loss = 4.280, lr = 0.001,
# batch no = 696 / 2323, train loss = 4.324, lr = 0.001,
# batch no = 928 / 2323, train loss = 4.169, lr = 0.001,
# batch no = 1160 / 2323, train loss = 4.510, lr = 0.001,
# batch no = 1392 / 2323, train loss = 4.455, lr = 0.001,
# batch no = 1624 / 2323, train loss = 4.274, lr = 0.001,
# batch no = 1856 / 2323, train loss = 3.991, lr = 0.001,
# batch no = 2088 / 2323, train loss = 4.356, lr = 0.001,
# batch no = 2320 / 2323, train loss = 4.465, lr = 0.001,
# Validation set perplexity : 99.083
# *************************************************
#
# Test set perplexity : 95.653
# Training over
# Epoch 48/50
# batch no = 0 / 2323, train loss = 5.091, lr = 0.001,
# batch no = 232 / 2323, train loss = 4.222, lr = 0.001,
# batch no = 464 / 2323, train loss = 4.304, lr = 0.001,
# batch no = 696 / 2323, train loss = 4.262, lr = 0.001,
# batch no = 928 / 2323, train loss = 4.063, lr = 0.001,
# batch no = 1160 / 2323, train loss = 4.398, lr = 0.001,
# batch no = 1392 / 2323, train loss = 4.458, lr = 0.001,
# batch no = 1624 / 2323, train loss = 4.345, lr = 0.001,
# batch no = 1856 / 2323, train loss = 4.075, lr = 0.001,
# batch no = 2088 / 2323, train loss = 4.330, lr = 0.001,
# batch no = 2320 / 2323, train loss = 4.360, lr = 0.001,
# Validation set perplexity : 99.066
# *************************************************
#
# Test set perplexity : 95.645
# Training over
# Epoch 49/50
# batch no = 0 / 2323, train loss = 5.104, lr = 0.001,
# batch no = 232 / 2323, train loss = 4.168, lr = 0.001,
# batch no = 464 / 2323, train loss = 4.250, lr = 0.001,
# batch no = 696 / 2323, train loss = 4.264, lr = 0.001,
# batch no = 928 / 2323, train loss = 4.175, lr = 0.001,
# batch no = 1160 / 2323, train loss = 4.404, lr = 0.001,
# batch no = 1392 / 2323, train loss = 4.370, lr = 0.001,
# batch no = 1624 / 2323, train loss = 4.312, lr = 0.001,
# batch no = 1856 / 2323, train loss = 3.957, lr = 0.001,
# batch no = 2088 / 2323, train loss = 4.375, lr = 0.001,
# batch no = 2320 / 2323, train loss = 4.475, lr = 0.001,
# Validation set perplexity : 99.065
# *************************************************
#
# Test set perplexity : 95.636
# Training over
# Epoch 50/50
# batch no = 0 / 2323, train loss = 5.079, lr = 0.001,
# batch no = 232 / 2323, train loss = 4.195, lr = 0.001,
# batch no = 464 / 2323, train loss = 4.319, lr = 0.001,
# batch no = 696 / 2323, train loss = 4.330, lr = 0.001,
# batch no = 928 / 2323, train loss = 4.177, lr = 0.001,
# batch no = 1160 / 2323, train loss = 4.485, lr = 0.001,
# batch no = 1392 / 2323, train loss = 4.446, lr = 0.001,
# batch no = 1624 / 2323, train loss = 4.265, lr = 0.001,
# batch no = 1856 / 2323, train loss = 4.086, lr = 0.001,
# batch no = 2088 / 2323, train loss = 4.396, lr = 0.001,
# batch no = 2320 / 2323, train loss = 4.386, lr = 0.001,
# Validation set perplexity : 99.065
# *************************************************
#
# Test set perplexity : 95.629
# Training over

# %%
#plot perplexity vs epoch of test and train data from json files
summary = {'LSTM Model' : [],
           'LSTM Dropout Model': [],
           'GRU Model': [],
           'GRU Dropout Model':[]}
with open('LSTM.json', mode='r', encoding='utf-8') as json_f:
    results_dict = json.load(json_f)
accuracies_regular_model = plt.figure()
plt.plot(range(1, len(results_dict['train_perp']) + 1),
             results_dict['train_perp'])
plt.plot(range(1, len(results_dict['test_perp']) + 1),
             results_dict['test_perp'])
plt.legend(['train','test'])
plt.title('Perplexity vs epoch for LSTM model')
plt.xlabel('epoch')
plt.ylabel('perplexity')
accuracies_regular_model.savefig('LSTM_perplexity_plot.png')
plt.show()
summary['LSTM Model'].append(min(results_dict['train_perp']))
summary['LSTM Model'].append(min(results_dict['test_perp']))
summary['LSTM Model'].append(min(results_dict['val_perp']))

with open('LSTM_dropout.json', mode='r', encoding='utf-8') as json_f:
    results_dict = json.load(json_f)
accuracies_dropout_model = plt.figure()
plt.plot(range(1, len(results_dict['train_perp']) + 1),
             results_dict['train_perp'])
plt.plot(range(1, len(results_dict['test_perp']) + 1),
             results_dict['test_perp'])
plt.legend(['train','test'])
plt.title('Perplexity vs epoch for LSTM dropout model')
plt.xlabel('epoch')
plt.ylabel('perplexity')
accuracies_dropout_model.savefig('LSTM_dropout_perplexity_plot.png')
plt.show()
summary['LSTM Dropout Model'].append(min(results_dict['train_perp']))
summary['LSTM Dropout Model'].append(min(results_dict['test_perp']))
summary['LSTM Dropout Model'].append(min(results_dict['val_perp']))

with open('GRU.json', mode='r', encoding='utf-8') as json_f:
    results_dict = json.load(json_f)
accuracies_wd_model = plt.figure()
plt.plot(range(1, len(results_dict['train_perp']) + 1),
             results_dict['train_perp'])
plt.plot(range(1, len(results_dict['test_perp']) + 1),
             results_dict['test_perp'])
plt.legend(['train','test'])
plt.title('Perplexity vs epoch for GRU model')
plt.xlabel('epoch')
plt.ylabel('perplexity')
accuracies_wd_model.savefig('GRU_perplexity_plot.png')
plt.show()
summary['GRU Model'].append(min(results_dict['train_perp']))
summary['GRU Model'].append(min(results_dict['test_perp']))
summary['GRU Model'].append(min(results_dict['val_perp']))

with open('GRU_dropout.json', mode='r', encoding='utf-8') as json_f:
    results_dict = json.load(json_f)
accuracies_bn_model = plt.figure()
plt.plot(range(1, len(results_dict['train_perp']) + 1),
             results_dict['train_perp'])
plt.plot(range(1, len(results_dict['test_perp']) + 1),
             results_dict['test_perp'])
plt.legend(['train','test'])
plt.title('Perplexity vs epoch for GRU dropout model')
plt.xlabel('epoch')
plt.ylabel('perplexity')
accuracies_bn_model.savefig('GRU_dropout_perplexity_plot.png')
plt.show()
summary['GRU Dropout Model'].append(min(results_dict['train_perp']))
summary['GRU Dropout Model'].append(min(results_dict['test_perp']))
summary['GRU Dropout Model'].append(min(results_dict['val_perp']))

# %%
print("{:<20} {:<20} {:<20} {:<20}".format('MODEL', 'VALIDATION', 'TRAIN', 'TEST'))
 
#print max train and test accuracy for each model, summarize in a table
for key, value in summary.items():
    train,test,val = value
    print("{:<20} {:<20} {:<20} {:<20}".format(key, val, train, test))
# Out:
# MODEL                VALIDATION           TRAIN                TEST
# LSTM Model           117.55855439700146   43.7041202800996     113.69518918580192
# LSTM Dropout Model   98.84896458605425    53.89457242217583    94.62093556488331
# GRU Model            122.83624405544253   43.67377965259323    118.7865216049553
# GRU Dropout Model    99.06497976474513    48.13819720721924    95.6290303721404
